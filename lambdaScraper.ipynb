# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
fighters_df = pd.read_csv('ufc_fighters_cleaned.csv')

url = "http://ufcstats.com/statistics/events/completed?page=all"
headers = {'User-Agent': 'Mozilla/5.0'}

response = requests.get(url, headers=headers)
response.raise_for_status()
soup = BeautifulSoup(response.content, 'html.parser')

first_tag = soup.select_one('a.b-link.b-link_style_black[href*="event-details"]')
first_event_link = first_tag['href'] if first_tag else None

print(first_event_link)
# Out:
# http://ufcstats.com/event-details/ed220e87bef0cc64

# %%
fight_links = []

if first_event_link:
    # fetch the single event page
    resp = requests.get(first_event_link, headers=headers)
    resp.raise_for_status()
    ev_soup = BeautifulSoup(resp.content, 'html.parser')

    # extract the event date
    date_el = ev_soup.find('li', class_='b-list__box-list-item')
    event_date = date_el.text.split(':')[-1].strip() if date_el else 'N/A'

    # find every fight row and pull out the onclick URL
    for row in ev_soup.select('tr.b-fight-details__table-row'):
        onclick = row.get('onclick','')
        if 'doNav' in onclick:
            fight_url = onclick.split("'")[1]
            fight_links.append({
                'url': fight_url,
                'event_date': event_date
            })

print(fight_links)
# Out:
# [{'url': 'http://ufcstats.com/fight-details/a3ee907c77544cde', 'event_date': 'September 27, 2025'}, {'url': 'http://ufcstats.com/fight-details/f5fb8b182020c59d', 'event_date': 'September 27, 2025'}, {'url': 'http://ufcstats.com/fight-details/38248c5d13f273e6', 'event_date': 'September 27, 2025'}, {'url': 'http://ufcstats.com/fight-details/1ff24d5f760e0491', 'event_date': 'September 27, 2025'}, {'url': 'http://ufcstats.com/fight-details/8abad36b4c5e4070', 'event_date': 'September 27, 2025'}, {'url': 'http://ufcstats.com/fight-details/dc31d3260dea7dcf', 'event_date': 'September 27, 2025'}, {'url': 'http://ufcstats.com/fight-details/93a0a19c2c1cfe66', 'event_date': 'September 27, 2025'}, {'url': 'http://ufcstats.com/fight-details/e2dc4fb7b5c0ce76', 'event_date': 'September 27, 2025'}, {'url': 'http://ufcstats.com/fight-details/81127436605d3c88', 'event_date': 'September 27, 2025'}, {'url': 'http://ufcstats.com/fight-details/44cd8c9f622e155f', 'event_date': 'September 27, 2025'}, {'url': 'http://ufcstats.com/fight-details/140937779a2466a7', 'event_date': 'September 27, 2025'}, {'url': 'http://ufcstats.com/fight-details/e35f7504d83b8b07', 'event_date': 'September 27, 2025'}]

# %%
def scrape_ufc_fight_details(url): # scrapes the stats from the url we input
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract method of victory
    method_tag = soup.find('i', class_='b-fight-details__text-item_first')
    method = method_tag.find('i', style="font-style: normal").text.strip() if method_tag else ''
    
    # Extract referee
    referee = ""
    referee_span = soup.select_one('i.b-fight-details__label:-soup-contains("Referee:") + span')
    if referee_span:
        referee = referee_span.text.strip()

    # Find fighter status (W/L) for the first fighter
    fighter_status_tag = soup.find('i', class_='b-fight-details__person-status')
    first_fighter_won = None
    if fighter_status_tag:
        status = fighter_status_tag.text.strip()
        first_fighter_won = 1 if status == "W" else 0
    

    # get the data from round 1 and the totals rows
    all_rows = []
    rows = soup.find_all('tr', class_='b-fight-details__table-row')

    for row in rows:
        columns = row.find_all('p', class_='b-fight-details__table-text')
        data = [col.get_text(strip=True) for col in columns]
        all_rows.append(data)
    
    totals = 1
    r1_totals = 3
    sigTotals = int(len(all_rows) / 2 + 1)
    r1_sigTotals = sigTotals + 2
    
    filtered_rows = []
    
    def is_valid_row(arr):
        needed_indexes = [totals, r1_totals, sigTotals, r1_sigTotals]
        for idx in needed_indexes:
            if idx < len(all_rows):  # Make sure index is valid
                arr.append(all_rows[idx])
    
    is_valid_row(filtered_rows)
    
    # Append method of victory and referee as a new array at the end
    filtered_rows.append([method, referee])
    filtered_rows.append(first_fighter_won)

    return filtered_rows

# Test with the example URL
url = 'http://ufcstats.com/fight-details/d05cb4c4135ce402'
data = scrape_ufc_fight_details(url)
print(data)
# Out:
# [['Michael Chandler', 'Paddy Pimblett', '0', '0', '11 of 28', '80 of 143', '39%', '55%', '20 of 39', '121 of 197', '4 of 7', '1 of 2', '57%', '50%', '0', '0', '0', '1', '2:44', '4:41'], ['Michael Chandler', 'Paddy Pimblett', '0', '0', '5 of 11', '16 of 40', '45%', '40%', '7 of 14', '25 of 50', '2 of 3', '0 of 0', '66%', '---', '0', '0', '0', '0', '2:10', '0:00'], ['Michael Chandler', 'Paddy Pimblett', '11 of 28', '80 of 143', '39%', '55%', '6 of 18', '61 of 119', '3 of 7', '4 of 5', '2 of 3', '15 of 19', '10 of 24', '43 of 96', '0 of 0', '4 of 5', '1 of 4', '33 of 42'], ['Michael Chandler', 'Paddy Pimblett', '5 of 11', '16 of 40', '45%', '40%', '4 of 10', '7 of 28', '1 of 1', '1 of 2', '0 of 0', '8 of 10', '4 of 7', '16 of 40', '0 of 0', '0 of 0', '1 of 4', '0 of 0'], ['KO/TKO', 'Kerry Hatley'], 0]

# %%
def format_fight_data_single_row(data): #formats the data extracted from a match into a dictionary
    if not data or len(data) < 4:
        return "Not enough data to format."
    
    # Extract fighter names for reference
    fighter1 = data[0][0]
    fighter2 = data[0][1]
    
    # Create a single row dictionary with p1_ and p2_ prefixes
    formatted_row = {
        "p1_fighter": fighter1,
        "p2_fighter": fighter2,
        
        # Totals (Row 1)
        "p1_KD": data[0][2],
        "p2_KD": data[0][3],
        "p1_SIG_STR": data[0][4],
        "p2_SIG_STR": data[0][5],
        "p1_SIG_STR_PCT": data[0][6],
        "p2_SIG_STR_PCT": data[0][7],
        "p1_TOTAL_STR": data[0][8],
        "p2_TOTAL_STR": data[0][9],
        "p1_TD": data[0][10],
        "p2_TD": data[0][11],
        "p1_TD_PCT": data[0][12],
        "p2_TD_PCT": data[0][13],
        "p1_SUB_ATT": data[0][14],
        "p2_SUB_ATT": data[0][15],
        "p1_REV": data[0][16],
        "p2_REV": data[0][17],
        "p1_CTRL": data[0][18],
        "p2_CTRL": data[0][19],
        
        # Round 1 Totals (Row 2)
        "p1_R1_KD": data[1][2],
        "p2_R1_KD": data[1][3],
        "p1_R1_SIG_STR": data[1][4],
        "p2_R1_SIG_STR": data[1][5],
        "p1_R1_SIG_STR_PCT": data[1][6],
        "p2_R1_SIG_STR_PCT": data[1][7],
        "p1_R1_TOTAL_STR": data[1][8],
        "p2_R1_TOTAL_STR": data[1][9],
        "p1_R1_TD": data[1][10],
        "p2_R1_TD": data[1][11],
        "p1_R1_TD_PCT": data[1][12],
        "p2_R1_TD_PCT": data[1][13],
        "p1_R1_SUB_ATT": data[1][14],
        "p2_R1_SUB_ATT": data[1][15],
        "p1_R1_REV": data[1][16],
        "p2_R1_REV": data[1][17],
        "p1_R1_CTRL": data[1][18],
        "p2_R1_CTRL": data[1][19],
        
        # Significant Strike Details (Row 3)
        "p1_SIG_STR_LANDED_ATTEMPTED": data[2][2],
        "p2_SIG_STR_LANDED_ATTEMPTED": data[2][3],
        "p1_SIG_STR_PCT_DETAILED": data[2][4],
        "p2_SIG_STR_PCT_DETAILED": data[2][5],
        "p1_HEAD_LANDED_ATTEMPTED": data[2][6],
        "p2_HEAD_LANDED_ATTEMPTED": data[2][7],
        "p1_BODY_LANDED_ATTEMPTED": data[2][8],
        "p2_BODY_LANDED_ATTEMPTED": data[2][9],
        "p1_LEG_LANDED_ATTEMPTED": data[2][10],
        "p2_LEG_LANDED_ATTEMPTED": data[2][11],
        "p1_DISTANCE_LANDED_ATTEMPTED": data[2][12],
        "p2_DISTANCE_LANDED_ATTEMPTED": data[2][13],
        "p1_CLINCH_LANDED_ATTEMPTED": data[2][14],
        "p2_CLINCH_LANDED_ATTEMPTED": data[2][15],
        "p1_GROUND_LANDED_ATTEMPTED": data[2][16],
        "p2_GROUND_LANDED_ATTEMPTED": data[2][17],
        
        # Round 1 Significant Strike Details (Row 4)
        "p1_R1_SIG_STR_LANDED_ATTEMPTED": data[3][2],
        "p2_R1_SIG_STR_LANDED_ATTEMPTED": data[3][3],
        "p1_R1_SIG_STR_PCT_DETAILED": data[3][4],
        "p2_R1_SIG_STR_PCT_DETAILED": data[3][5],
        "p1_R1_HEAD_LANDED_ATTEMPTED": data[3][6],
        "p2_R1_HEAD_LANDED_ATTEMPTED": data[3][7],
        "p1_R1_BODY_LANDED_ATTEMPTED": data[3][8],
        "p2_R1_BODY_LANDED_ATTEMPTED": data[3][9],
        "p1_R1_LEG_LANDED_ATTEMPTED": data[3][10],
        "p2_R1_LEG_LANDED_ATTEMPTED": data[3][11],
        "p1_R1_DISTANCE_LANDED_ATTEMPTED": data[3][12],
        "p2_R1_DISTANCE_LANDED_ATTEMPTED": data[3][13],
        "p1_R1_CLINCH_LANDED_ATTEMPTED": data[3][14],
        "p2_R1_CLINCH_LANDED_ATTEMPTED": data[3][15],
        "p1_R1_GROUND_LANDED_ATTEMPTED": data[3][16],
        "p2_R1_GROUND_LANDED_ATTEMPTED": data[3][17],

        "method": data[4][0],
        "referee": data[4][1],
        "winner": data[5]
    }
    
    # Print column headers once (useful for CSV export)
    print(",".join(formatted_row.keys()))
    
    # Print the values as a single row
    print(",".join(str(val) for val in formatted_row.values()))
    
    return formatted_row

# Call the function with your scraped data
formatted_row = format_fight_data_single_row(data)
print(formatted_row)
# Out:
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Michael Chandler,Paddy Pimblett,0,0,11 of 28,80 of 143,39%,55%,20 of 39,121 of 197,4 of 7,1 of 2,57%,50%,0,0,0,1,2:44,4:41,0,0,5 of 11,16 of 40,45%,40%,7 of 14,25 of 50,2 of 3,0 of 0,66%,---,0,0,0,0,2:10,0:00,11 of 28,80 of 143,39%,55%,6 of 18,61 of 119,3 of 7,4 of 5,2 of 3,15 of 19,10 of 24,43 of 96,0 of 0,4 of 5,1 of 4,33 of 42,5 of 11,16 of 40,45%,40%,4 of 10,7 of 28,1 of 1,1 of 2,0 of 0,8 of 10,4 of 7,16 of 40,0 of 0,0 of 0,1 of 4,0 of 0,KO/TKO,Kerry Hatley,0
# {'p1_fighter': 'Michael Chandler', 'p2_fighter': 'Paddy Pimblett', 'p1_KD': '0', 'p2_KD': '0', 'p1_SIG_STR': '11 of 28', 'p2_SIG_STR': '80 of 143', 'p1_SIG_STR_PCT': '39%', 'p2_SIG_STR_PCT': '55%', 'p1_TOTAL_STR': '20 of 39', 'p2_TOTAL_STR': '121 of 197', 'p1_TD': '4 of 7', 'p2_TD': '1 of 2', 'p1_TD_PCT': '57%', 'p2_TD_PCT': '50%', 'p1_SUB_ATT': '0', 'p2_SUB_ATT': '0', 'p1_REV': '0', 'p2_REV': '1', 'p1_CTRL': '2:44', 'p2_CTRL': '4:41', 'p1_R1_KD': '0', 'p2_R1_KD': '0', 'p1_R1_SIG_STR': '5 of 11', 'p2_R1_SIG_STR': '16 of 40', 'p1_R1_SIG_STR_PCT': '45%', 'p2_R1_SIG_STR_PCT': '40%', 'p1_R1_TOTAL_STR': '7 of 14', 'p2_R1_TOTAL_STR': '25 of 50', 'p1_R1_TD': '2 of 3', 'p2_R1_TD': '0 of 0', 'p1_R1_TD_PCT': '66%', 'p2_R1_TD_PCT': '---', 'p1_R1_SUB_ATT': '0', 'p2_R1_SUB_ATT': '0', 'p1_R1_REV': '0', 'p2_R1_REV': '0', 'p1_R1_CTRL': '2:10', 'p2_R1_CTRL': '0:00', 'p1_SIG_STR_LANDED_ATTEMPTED': '11 of 28', 'p2_SIG_STR_LANDED_ATTEMPTED': '80 of 143', 'p1_SIG_STR_PCT_DETAILED': '39%', 'p2_SIG_STR_PCT_DETAILED': '55%', 'p1_HEAD_LANDED_ATTEMPTED': '6 of 18', 'p2_HEAD_LANDED_ATTEMPTED': '61 of 119', 'p1_BODY_LANDED_ATTEMPTED': '3 of 7', 'p2_BODY_LANDED_ATTEMPTED': '4 of 5', 'p1_LEG_LANDED_ATTEMPTED': '2 of 3', 'p2_LEG_LANDED_ATTEMPTED': '15 of 19', 'p1_DISTANCE_LANDED_ATTEMPTED': '10 of 24', 'p2_DISTANCE_LANDED_ATTEMPTED': '43 of 96', 'p1_CLINCH_LANDED_ATTEMPTED': '0 of 0', 'p2_CLINCH_LANDED_ATTEMPTED': '4 of 5', 'p1_GROUND_LANDED_ATTEMPTED': '1 of 4', 'p2_GROUND_LANDED_ATTEMPTED': '33 of 42', 'p1_R1_SIG_STR_LANDED_ATTEMPTED': '5 of 11', 'p2_R1_SIG_STR_LANDED_ATTEMPTED': '16 of 40', 'p1_R1_SIG_STR_PCT_DETAILED': '45%', 'p2_R1_SIG_STR_PCT_DETAILED': '40%', 'p1_R1_HEAD_LANDED_ATTEMPTED': '4 of 10', 'p2_R1_HEAD_LANDED_ATTEMPTED': '7 of 28', 'p1_R1_BODY_LANDED_ATTEMPTED': '1 of 1', 'p2_R1_BODY_LANDED_ATTEMPTED': '1 of 2', 'p1_R1_LEG_LANDED_ATTEMPTED': '0 of 0', 'p2_R1_LEG_LANDED_ATTEMPTED': '8 of 10', 'p1_R1_DISTANCE_LANDED_ATTEMPTED': '4 of 7', 'p2_R1_DISTANCE_LANDED_ATTEMPTED': '16 of 40', 'p1_R1_CLINCH_LANDED_ATTEMPTED': '0 of 0', 'p2_R1_CLINCH_LANDED_ATTEMPTED': '0 of 0', 'p1_R1_GROUND_LANDED_ATTEMPTED': '1 of 4', 'p2_R1_GROUND_LANDED_ATTEMPTED': '0 of 0', 'method': 'KO/TKO', 'referee': 'Kerry Hatley', 'winner': 0}

# %%
def process_multiple_fights_with_date(url_date_list): # gets the data from every match and creates a dataframe from it 
    all_fights_data = []
    
    for item in url_date_list:
        url = item['url']
        event_date = item['event_date']
        try:
            fight_data = scrape_ufc_fight_details(url)
            formatted_row = format_fight_data_single_row(fight_data)  
            if isinstance(formatted_row, dict):
                formatted_row['event_date'] = event_date  # Add date to row
                all_fights_data.append(formatted_row)
            else:
                print(f"Error processing {url}: {formatted_row}")
        except Exception as e:
            print(f"Error processing {url}: {str(e)}")
    
    return pd.DataFrame(all_fights_data) if all_fights_data else "No data processed"

fights_df = process_multiple_fights_with_date(fight_links)
fights_df.head()
# Out:
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Carlos Ulberg,Dominick Reyes,1,0,11 of 17,5 of 11,64%,45%,11 of 17,5 of 11,0 of 0,0 of 0,---,---,0,0,0,0,0:03,0:00,1,0,11 of 17,5 of 11,64%,45%,11 of 17,5 of 11,0 of 0,0 of 0,---,---,0,0,0,0,0:03,0:00,11 of 17,5 of 11,64%,45%,6 of 9,0 of 5,2 of 3,1 of 1,3 of 5,4 of 5,9 of 15,5 of 11,0 of 0,0 of 0,2 of 2,0 of 0,11 of 17,5 of 11,64%,45%,6 of 9,0 of 5,2 of 3,1 of 1,3 of 5,4 of 5,9 of 15,5 of 11,0 of 0,0 of 0,2 of 2,0 of 0,KO/TKO,Marc Goddard,1
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Jimmy Crute,Ivan Erslan,0,0,12 of 16,10 of 14,75%,71%,12 of 16,10 of 14,2 of 4,0 of 0,50%,---,1,0,1,0,2:08,0:05,0,0,12 of 16,10 of 14,75%,71%,12 of 16,10 of 14,2 of 4,0 of 0,50%,---,1,0,1,0,2:08,0:05,12 of 16,10 of 14,75%,71%,3 of 7,9 of 13,1 of 1,0 of 0,8 of 8,1 of 1,9 of 12,10 of 14,0 of 0,0 of 0,3 of 4,0 of 0,12 of 16,10 of 14,75%,71%,3 of 7,9 of 13,1 of 1,0 of 0,8 of 8,1 of 1,9 of 12,10 of 14,0 of 0,0 of 0,3 of 4,0 of 0,Submission,Mike Beltran,1
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Jack Jenkins,Ramon Taveras,0,0,65 of 109,43 of 113,59%,38%,73 of 123,68 of 142,3 of 6,0 of 4,50%,0%,1,0,0,1,3:58,1:39,0,0,32 of 56,16 of 43,57%,37%,32 of 56,16 of 43,0 of 0,0 of 1,---,0%,0,0,0,0,0:00,0:02,65 of 109,43 of 113,59%,38%,29 of 68,36 of 98,16 of 21,6 of 14,20 of 20,1 of 1,58 of 95,38 of 106,4 of 5,0 of 1,3 of 9,5 of 6,32 of 56,16 of 43,57%,37%,14 of 33,11 of 34,11 of 16,4 of 8,7 of 7,1 of 1,29 of 52,16 of 43,3 of 4,0 of 0,0 of 0,0 of 0,Decision - Unanimous,Marc Goddard,1
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Jake Matthews,Neil Magny,0,0,18 of 44,31 of 57,40%,54%,28 of 54,73 of 103,0 of 1,3 of 5,0%,60%,3,1,1,0,4:43,2:46,0,0,9 of 20,18 of 32,45%,56%,10 of 21,24 of 38,0 of 0,1 of 2,---,50%,1,0,1,0,0:22,1:08,18 of 44,31 of 57,40%,54%,11 of 36,28 of 52,4 of 4,1 of 2,3 of 4,2 of 3,15 of 37,29 of 52,2 of 4,2 of 5,1 of 3,0 of 0,9 of 20,18 of 32,45%,56%,4 of 14,16 of 30,3 of 3,0 of 0,2 of 3,2 of 2,8 of 18,18 of 31,1 of 2,0 of 1,0 of 0,0 of 0,Submission,Jim Perdios,0
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Tom Nolan,Charlie Campbell,0,0,26 of 61,15 of 42,42%,35%,33 of 69,15 of 42,1 of 1,0 of 1,100%,0%,1,0,0,0,0:34,0:18,0,0,26 of 61,15 of 42,42%,35%,33 of 69,15 of 42,1 of 1,0 of 1,100%,0%,1,0,0,0,0:34,0:18,26 of 61,15 of 42,42%,35%,13 of 35,7 of 30,9 of 20,1 of 5,4 of 6,7 of 7,23 of 55,14 of 39,3 of 6,0 of 1,0 of 0,1 of 2,26 of 61,15 of 42,42%,35%,13 of 35,7 of 30,9 of 20,1 of 5,4 of 6,7 of 7,23 of 55,14 of 39,3 of 6,0 of 1,0 of 0,1 of 2,Submission,Jim Perdios,1
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Navajo Stirling,Rodolfo Bellato,0,0,81 of 158,43 of 89,51%,48%,101 of 193,62 of 111,1 of 4,2 of 6,25%,33%,0,0,0,0,3:53,2:23,0,0,37 of 62,15 of 33,59%,45%,41 of 67,20 of 38,0 of 2,0 of 0,0%,---,0,0,0,0,0:58,0:40,81 of 158,43 of 89,51%,48%,44 of 102,21 of 60,35 of 53,12 of 19,2 of 3,10 of 10,70 of 145,39 of 81,10 of 12,4 of 6,1 of 1,0 of 2,37 of 62,15 of 33,59%,45%,21 of 37,4 of 17,15 of 23,5 of 10,1 of 2,6 of 6,32 of 56,13 of 30,5 of 6,2 of 3,0 of 0,0 of 0,Decision - Unanimous,Mike Beltran,1
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Cam Rowston,Andre Petroski,1,0,12 of 36,7 of 13,33%,53%,20 of 48,7 of 13,0 of 0,0 of 0,---,---,0,0,0,0,0:36,0:00,1,0,12 of 36,7 of 13,33%,53%,20 of 48,7 of 13,0 of 0,0 of 0,---,---,0,0,0,0,0:36,0:00,12 of 36,7 of 13,33%,53%,8 of 31,0 of 4,1 of 2,0 of 1,3 of 3,7 of 8,8 of 19,7 of 13,0 of 0,0 of 0,4 of 17,0 of 0,12 of 36,7 of 13,33%,53%,8 of 31,0 of 4,1 of 2,0 of 1,3 of 3,7 of 8,8 of 19,7 of 13,0 of 0,0 of 0,4 of 17,0 of 0,KO/TKO,Steve Perceval,1
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Jamie Mullarkey,Rolando Bedoya,0,0,43 of 89,46 of 116,48%,39%,47 of 94,55 of 129,3 of 17,0 of 0,17%,---,0,1,0,0,5:41,0:07,0,0,3 of 8,5 of 10,37%,50%,3 of 9,8 of 14,2 of 2,0 of 0,100%,---,0,0,0,0,3:49,0:00,43 of 89,46 of 116,48%,39%,32 of 74,32 of 93,7 of 10,8 of 13,4 of 5,6 of 10,40 of 82,37 of 99,3 of 6,9 of 16,0 of 1,0 of 1,3 of 8,5 of 10,37%,50%,1 of 5,2 of 5,0 of 1,0 of 2,2 of 2,3 of 3,3 of 7,5 of 9,0 of 0,0 of 0,0 of 1,0 of 1,Decision - Unanimous,Matt Wynne,1
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Colby Thicknesse,Josias Musasa,0,0,62 of 111,43 of 89,55%,48%,126 of 199,62 of 118,2 of 14,1 of 2,14%,50%,1,0,0,0,7:45,0:52,0,0,43 of 75,12 of 27,57%,44%,72 of 111,18 of 36,1 of 6,1 of 2,16%,50%,1,0,0,0,2:43,0:11,62 of 111,43 of 89,55%,48%,48 of 95,26 of 61,8 of 10,7 of 10,6 of 6,10 of 18,15 of 31,27 of 62,4 of 6,16 of 25,43 of 74,0 of 2,43 of 75,12 of 27,57%,44%,38 of 70,9 of 20,2 of 2,0 of 1,3 of 3,3 of 6,6 of 12,9 of 20,0 of 1,3 of 5,37 of 62,0 of 2,Decision - Unanimous,Jim Perdios,1
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Michelle Montague,Luana Carolina,0,0,41 of 88,48 of 82,46%,58%,99 of 164,75 of 115,5 of 7,0 of 0,71%,---,0,1,0,0,10:43,0:00,0,0,10 of 32,24 of 36,31%,66%,25 of 56,39 of 52,1 of 2,0 of 0,50%,---,0,1,0,0,2:44,0:00,41 of 88,48 of 82,46%,58%,34 of 77,31 of 60,6 of 9,5 of 6,1 of 2,12 of 16,12 of 36,46 of 77,1 of 1,1 of 3,28 of 51,1 of 2,10 of 32,24 of 36,31%,66%,8 of 28,11 of 20,2 of 3,3 of 4,0 of 1,10 of 12,5 of 24,23 of 34,0 of 0,1 of 2,5 of 8,0 of 0,Decision - Unanimous,Steve Perceval,1
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Brando Pericic,Elisha Ellison,0,0,29 of 49,3 of 9,59%,33%,30 of 50,3 of 9,0 of 0,0 of 2,---,0%,0,0,0,0,0:29,0:13,0,0,29 of 49,3 of 9,59%,33%,30 of 50,3 of 9,0 of 0,0 of 2,---,0%,0,0,0,0,0:29,0:13,29 of 49,3 of 9,59%,33%,23 of 42,2 of 8,2 of 3,1 of 1,4 of 4,0 of 0,11 of 20,2 of 8,12 of 18,1 of 1,6 of 11,0 of 0,29 of 49,3 of 9,59%,33%,23 of 42,2 of 8,2 of 3,1 of 1,4 of 4,0 of 0,11 of 20,2 of 8,12 of 18,1 of 1,6 of 11,0 of 0,KO/TKO,Mike Beltran,1
# p1_fighter,p2_fighter,p1_KD,p2_KD,p1_SIG_STR,p2_SIG_STR,p1_SIG_STR_PCT,p2_SIG_STR_PCT,p1_TOTAL_STR,p2_TOTAL_STR,p1_TD,p2_TD,p1_TD_PCT,p2_TD_PCT,p1_SUB_ATT,p2_SUB_ATT,p1_REV,p2_REV,p1_CTRL,p2_CTRL,p1_R1_KD,p2_R1_KD,p1_R1_SIG_STR,p2_R1_SIG_STR,p1_R1_SIG_STR_PCT,p2_R1_SIG_STR_PCT,p1_R1_TOTAL_STR,p2_R1_TOTAL_STR,p1_R1_TD,p2_R1_TD,p1_R1_TD_PCT,p2_R1_TD_PCT,p1_R1_SUB_ATT,p2_R1_SUB_ATT,p1_R1_REV,p2_R1_REV,p1_R1_CTRL,p2_R1_CTRL,p1_SIG_STR_LANDED_ATTEMPTED,p2_SIG_STR_LANDED_ATTEMPTED,p1_SIG_STR_PCT_DETAILED,p2_SIG_STR_PCT_DETAILED,p1_HEAD_LANDED_ATTEMPTED,p2_HEAD_LANDED_ATTEMPTED,p1_BODY_LANDED_ATTEMPTED,p2_BODY_LANDED_ATTEMPTED,p1_LEG_LANDED_ATTEMPTED,p2_LEG_LANDED_ATTEMPTED,p1_DISTANCE_LANDED_ATTEMPTED,p2_DISTANCE_LANDED_ATTEMPTED,p1_CLINCH_LANDED_ATTEMPTED,p2_CLINCH_LANDED_ATTEMPTED,p1_GROUND_LANDED_ATTEMPTED,p2_GROUND_LANDED_ATTEMPTED,p1_R1_SIG_STR_LANDED_ATTEMPTED,p2_R1_SIG_STR_LANDED_ATTEMPTED,p1_R1_SIG_STR_PCT_DETAILED,p2_R1_SIG_STR_PCT_DETAILED,p1_R1_HEAD_LANDED_ATTEMPTED,p2_R1_HEAD_LANDED_ATTEMPTED,p1_R1_BODY_LANDED_ATTEMPTED,p2_R1_BODY_LANDED_ATTEMPTED,p1_R1_LEG_LANDED_ATTEMPTED,p2_R1_LEG_LANDED_ATTEMPTED,p1_R1_DISTANCE_LANDED_ATTEMPTED,p2_R1_DISTANCE_LANDED_ATTEMPTED,p1_R1_CLINCH_LANDED_ATTEMPTED,p2_R1_CLINCH_LANDED_ATTEMPTED,p1_R1_GROUND_LANDED_ATTEMPTED,p2_R1_GROUND_LANDED_ATTEMPTED,method,referee,winner
# Loma Lookboonmee,Alexia Thainara,0,0,30 of 61,44 of 107,49%,41%,67 of 102,110 of 202,0 of 1,5 of 11,0%,45%,0,1,0,0,0:11,10:02,0,0,15 of 21,24 of 48,71%,50%,28 of 36,35 of 64,0 of 1,2 of 4,0%,50%,0,1,0,0,0:00,2:39,30 of 61,44 of 107,49%,41%,14 of 37,29 of 78,12 of 19,7 of 13,4 of 5,8 of 16,25 of 51,23 of 70,5 of 10,9 of 18,0 of 0,12 of 19,15 of 21,24 of 48,71%,50%,9 of 14,16 of 35,3 of 3,2 of 4,3 of 4,6 of 9,14 of 20,12 of 30,1 of 1,0 of 1,0 of 0,12 of 17,Decision - Unanimous,Matt Wynne,0
#       p1_fighter        p2_fighter p1_KD p2_KD p1_SIG_STR p2_SIG_STR  \
# 0  Carlos Ulberg    Dominick Reyes     1     0   11 of 17    5 of 11
# 1    Jimmy Crute       Ivan Erslan     0     0   12 of 16   10 of 14
# 2   Jack Jenkins     Ramon Taveras     0     0  65 of 109  43 of 113
# 3  Jake Matthews        Neil Magny     0     0   18 of 44   31 of 57
# 4      Tom Nolan  Charlie Campbell     0     0   26 of 61   15 of 42
#
#   p1_SIG_STR_PCT p2_SIG_STR_PCT p1_TOTAL_STR p2_TOTAL_STR   p1_TD   p2_TD  \
# 0            64%            45%     11 of 17      5 of 11  0 of 0  0 of 0
# 1            75%            71%     12 of 16     10 of 14  2 of 4  0 of 0
# 2            59%            38%    73 of 123    68 of 142  3 of 6  0 of 4
# 3            40%            54%     28 of 54    73 of 103  0 of 1  3 of 5
# 4            42%            35%     33 of 69     15 of 42  1 of 1  0 of 1
#
#   p1_TD_PCT p2_TD_PCT p1_SUB_ATT p2_SUB_ATT p1_REV p2_REV p1_CTRL p2_CTRL  \
# 0       ---       ---          0          0      0      0    0:03    0:00
# 1       50%       ---          1          0      1      0    2:08    0:05
# 2       50%        0%          1          0      0      1    3:58    1:39
# 3        0%       60%          3          1      1      0    4:43    2:46
# 4      100%        0%          1          0      0      0    0:34    0:18
#
#   p1_R1_KD p2_R1_KD p1_R1_SIG_STR p2_R1_SIG_STR p1_R1_SIG_STR_PCT  \
# 0        1        0      11 of 17       5 of 11               64%
# 1        0        0      12 of 16      10 of 14               75%
# 2        0        0      32 of 56      16 of 43               57%
# 3        0        0       9 of 20      18 of 32               45%
# 4        0        0      26 of 61      15 of 42               42%
#
#   p2_R1_SIG_STR_PCT p1_R1_TOTAL_STR p2_R1_TOTAL_STR p1_R1_TD p2_R1_TD  \
# 0               45%        11 of 17         5 of 11   0 of 0   0 of 0
# 1               71%        12 of 16        10 of 14   2 of 4   0 of 0
# 2               37%        32 of 56        16 of 43   0 of 0   0 of 1
# 3               56%        10 of 21        24 of 38   0 of 0   1 of 2
# 4               35%        33 of 69        15 of 42   1 of 1   0 of 1
#
#   p1_R1_TD_PCT p2_R1_TD_PCT p1_R1_SUB_ATT p2_R1_SUB_ATT p1_R1_REV p2_R1_REV  \
# 0          ---          ---             0             0         0         0
# 1          50%          ---             1             0         1         0
# 2          ---           0%             0             0         0         0
# 3          ---          50%             1             0         1         0
# 4         100%           0%             1             0         0         0
#
#   p1_R1_CTRL p2_R1_CTRL p1_SIG_STR_LANDED_ATTEMPTED  \
# 0       0:03       0:00                    11 of 17
# 1       2:08       0:05                    12 of 16
# 2       0:00       0:02                   65 of 109
# 3       0:22       1:08                    18 of 44
# 4       0:34       0:18                    26 of 61
#
#   p2_SIG_STR_LANDED_ATTEMPTED p1_SIG_STR_PCT_DETAILED p2_SIG_STR_PCT_DETAILED  \
# 0                     5 of 11                     64%                     45%
# 1                    10 of 14                     75%                     71%
# 2                   43 of 113                     59%                     38%
# 3                    31 of 57                     40%                     54%
# 4                    15 of 42                     42%                     35%
#
#   p1_HEAD_LANDED_ATTEMPTED p2_HEAD_LANDED_ATTEMPTED p1_BODY_LANDED_ATTEMPTED  \
# 0                   6 of 9                   0 of 5                   2 of 3
# 1                   3 of 7                  9 of 13                   1 of 1
# 2                 29 of 68                 36 of 98                 16 of 21
# 3                 11 of 36                 28 of 52                   4 of 4
# 4                 13 of 35                  7 of 30                  9 of 20
#
#   p2_BODY_LANDED_ATTEMPTED p1_LEG_LANDED_ATTEMPTED p2_LEG_LANDED_ATTEMPTED  \
# 0                   1 of 1                  3 of 5                  4 of 5
# 1                   0 of 0                  8 of 8                  1 of 1
# 2                  6 of 14                20 of 20                  1 of 1
# 3                   1 of 2                  3 of 4                  2 of 3
# 4                   1 of 5                  4 of 6                  7 of 7
#
#   p1_DISTANCE_LANDED_ATTEMPTED p2_DISTANCE_LANDED_ATTEMPTED  \
# 0                      9 of 15                      5 of 11
# 1                      9 of 12                     10 of 14
# 2                     58 of 95                    38 of 106
# 3                     15 of 37                     29 of 52
# 4                     23 of 55                     14 of 39
#
#   p1_CLINCH_LANDED_ATTEMPTED p2_CLINCH_LANDED_ATTEMPTED  \
# 0                     0 of 0                     0 of 0
# 1                     0 of 0                     0 of 0
# 2                     4 of 5                     0 of 1
# 3                     2 of 4                     2 of 5
# 4                     3 of 6                     0 of 1
#
#   p1_GROUND_LANDED_ATTEMPTED p2_GROUND_LANDED_ATTEMPTED  \
# 0                     2 of 2                     0 of 0
# 1                     3 of 4                     0 of 0
# 2                     3 of 9                     5 of 6
# 3                     1 of 3                     0 of 0
# 4                     0 of 0                     1 of 2
#
#   p1_R1_SIG_STR_LANDED_ATTEMPTED p2_R1_SIG_STR_LANDED_ATTEMPTED  \
# 0                       11 of 17                        5 of 11
# 1                       12 of 16                       10 of 14
# 2                       32 of 56                       16 of 43
# 3                        9 of 20                       18 of 32
# 4                       26 of 61                       15 of 42
#
#   p1_R1_SIG_STR_PCT_DETAILED p2_R1_SIG_STR_PCT_DETAILED  \
# 0                        64%                        45%
# 1                        75%                        71%
# 2                        57%                        37%
# 3                        45%                        56%
# 4                        42%                        35%
#
#   p1_R1_HEAD_LANDED_ATTEMPTED p2_R1_HEAD_LANDED_ATTEMPTED  \
# 0                      6 of 9                      0 of 5
# 1                      3 of 7                     9 of 13
# 2                    14 of 33                    11 of 34
# 3                     4 of 14                    16 of 30
# 4                    13 of 35                     7 of 30
#
#   p1_R1_BODY_LANDED_ATTEMPTED p2_R1_BODY_LANDED_ATTEMPTED  \
# 0                      2 of 3                      1 of 1
# 1                      1 of 1                      0 of 0
# 2                    11 of 16                      4 of 8
# 3                      3 of 3                      0 of 0
# 4                     9 of 20                      1 of 5
#
#   p1_R1_LEG_LANDED_ATTEMPTED p2_R1_LEG_LANDED_ATTEMPTED  \
# 0                     3 of 5                     4 of 5
# 1                     8 of 8                     1 of 1
# 2                     7 of 7                     1 of 1
# 3                     2 of 3                     2 of 2
# 4                     4 of 6                     7 of 7
#
#   p1_R1_DISTANCE_LANDED_ATTEMPTED p2_R1_DISTANCE_LANDED_ATTEMPTED  \
# 0                         9 of 15                         5 of 11
# 1                         9 of 12                        10 of 14
# 2                        29 of 52                        16 of 43
# 3                         8 of 18                        18 of 31
# 4                        23 of 55                        14 of 39
#
#   p1_R1_CLINCH_LANDED_ATTEMPTED p2_R1_CLINCH_LANDED_ATTEMPTED  \
# 0                        0 of 0                        0 of 0
# 1                        0 of 0                        0 of 0
# 2                        3 of 4                        0 of 0
# 3                        1 of 2                        0 of 1
# 4                        3 of 6                        0 of 1
#
#   p1_R1_GROUND_LANDED_ATTEMPTED p2_R1_GROUND_LANDED_ATTEMPTED  \
# 0                        2 of 2                        0 of 0
# 1                        3 of 4                        0 of 0
# 2                        0 of 0                        0 of 0
# 3                        0 of 0                        0 of 0
# 4                        0 of 0                        1 of 2
#
#                  method       referee  winner          event_date
# 0                KO/TKO  Marc Goddard       1  September 27, 2025
# 1            Submission  Mike Beltran       1  September 27, 2025
# 2  Decision - Unanimous  Marc Goddard       1  September 27, 2025
# 3            Submission   Jim Perdios       0  September 27, 2025
# 4            Submission   Jim Perdios       1  September 27, 2025

# %%
#clean fights_df

#replace '--' values and turn percents to decimals
percent_cols = ['p1_SIG_STR_PCT', 'p2_SIG_STR_PCT', 'p1_TD_PCT', 'p2_TD_PCT', 'p1_R1_SIG_STR_PCT', 'p2_R1_SIG_STR_PCT', 'p1_R1_TD_PCT', 'p2_R1_TD_PCT', 'p1_SIG_STR_PCT_DETAILED', 'p2_SIG_STR_PCT_DETAILED', 'p1_R1_SIG_STR_PCT_DETAILED', 'p2_R1_SIG_STR_PCT_DETAILED']
for col in percent_cols:
    fights_df[col] = (
        fights_df[col]
        .astype(str)
        .replace({'--': np.nan, '---': np.nan})  # Handle missing values first
        .str.replace('%', '', regex=False)  # Remove percentage symbols
        .str.strip()  # Clean whitespace
        .astype(float) / 100  # Convert to decimal
    )


#format event date
# fights_df['event_date'] = pd.to_datetime(fights_df['event_date'], errors='coerce')
#format event date - clean and standardize first
def clean_date_string(s):
    if pd.isna(s):
        return s
    s = str(s).strip()  # remove leading/trailing spaces
    s = s.strip('"').strip("'")  # remove quotes if any
    s = s.split(' ')[0]  # keep only date part, ignore time
    return s

fights_df['event_date'] = fights_df['event_date'].apply(clean_date_string)
fights_df['event_date'] = pd.to_datetime(fights_df['event_date'], errors='coerce')


# columns to split
cols_to_split = ['p1_SIG_STR', 'p2_SIG_STR', 'p1_TOTAL_STR', 'p2_TOTAL_STR', 'p1_TD', 'p2_TD', 'p1_R1_SIG_STR', 'p2_R1_SIG_STR', 'p1_R1_TOTAL_STR', 'p2_R1_TOTAL_STR', 'p1_R1_TD', 'p2_R1_TD', 'p1_SIG_STR_LANDED_ATTEMPTED', 'p2_SIG_STR_LANDED_ATTEMPTED', 'p1_HEAD_LANDED_ATTEMPTED', 'p2_HEAD_LANDED_ATTEMPTED', 'p1_BODY_LANDED_ATTEMPTED', 'p2_BODY_LANDED_ATTEMPTED', 'p1_LEG_LANDED_ATTEMPTED', 'p2_LEG_LANDED_ATTEMPTED', 'p1_DISTANCE_LANDED_ATTEMPTED', 'p2_DISTANCE_LANDED_ATTEMPTED', 'p1_CLINCH_LANDED_ATTEMPTED', 'p2_CLINCH_LANDED_ATTEMPTED', 'p1_GROUND_LANDED_ATTEMPTED', 'p2_GROUND_LANDED_ATTEMPTED', 'p1_R1_SIG_STR_LANDED_ATTEMPTED', 'p2_R1_SIG_STR_LANDED_ATTEMPTED', 'p1_R1_HEAD_LANDED_ATTEMPTED', 'p2_R1_HEAD_LANDED_ATTEMPTED', 'p1_R1_BODY_LANDED_ATTEMPTED', 'p2_R1_BODY_LANDED_ATTEMPTED', 'p1_R1_LEG_LANDED_ATTEMPTED', 'p2_R1_LEG_LANDED_ATTEMPTED', 'p1_R1_DISTANCE_LANDED_ATTEMPTED', 'p2_R1_DISTANCE_LANDED_ATTEMPTED', 'p1_R1_CLINCH_LANDED_ATTEMPTED', 'p2_R1_CLINCH_LANDED_ATTEMPTED', 'p1_R1_GROUND_LANDED_ATTEMPTED', 'p2_R1_GROUND_LANDED_ATTEMPTED']

#Loop over them, split into “_LANDED” and “_ATTEMPTED”, convert to ints
for col in cols_to_split:
    # decide new column names
    if col.endswith('_LANDED_ATTEMPTED'):
        base = col.rsplit('_', 2)[0]       # turns 'p1_HEAD_LANDED_ATTEMPTED' → 'p1_HEAD'
        landed_col    = f"{base}_LANDED"
        attempted_col = f"{base}_ATTEMPTED"
    else:
        # for columns like 'p1_SIG_STR'
        landed_col    = f"{col}_LANDED"
        attempted_col = f"{col}_ATTEMPTED"

    # split “63 of 129” → ['63','129'], then to numeric
    fights_df[[landed_col, attempted_col]] = (
        fights_df[col]
          .str.split(' of ', expand=True)
          .astype(int)
    )

# Drop the originals
fights_df.drop(columns=cols_to_split, inplace=True)


# time collumns needing reformatting
time_cols = ['p1_CTRL', 'p2_CTRL', 'p1_R1_CTRL', 'p2_R1_CTRL' ]

#Convert each to total seconds
for col in time_cols:
    # Replace non-time strings with NaN
    fights_df[col] = fights_df[col].replace({'--': np.nan, '---': np.nan})
    
    # Convert to "00:MM:SS" format then to seconds
    fights_df[col] = (
        pd.to_timedelta('00:' + fights_df[col].fillna('00:00'), errors='coerce')
        .dt.total_seconds()
        .astype('Int64')  # Allows integer NaNs
    )

fights_df.head(10)
# Out:
# /var/folders/nc/04zwxn450f3cllk4tzq8_fp40000gn/T/ipykernel_53303/588613312.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   fights_df['event_date'] = pd.to_datetime(fights_df['event_date'], errors='coerce')
#           p1_fighter        p2_fighter p1_KD p2_KD  p1_SIG_STR_PCT  \
# 0      Carlos Ulberg    Dominick Reyes     1     0            0.64
# 1        Jimmy Crute       Ivan Erslan     0     0            0.75
# 2       Jack Jenkins     Ramon Taveras     0     0            0.59
# 3      Jake Matthews        Neil Magny     0     0            0.40
# 4          Tom Nolan  Charlie Campbell     0     0            0.42
# 5    Navajo Stirling   Rodolfo Bellato     0     0            0.51
# 6        Cam Rowston    Andre Petroski     1     0            0.33
# 7    Jamie Mullarkey    Rolando Bedoya     0     0            0.48
# 8   Colby Thicknesse     Josias Musasa     0     0            0.55
# 9  Michelle Montague    Luana Carolina     0     0            0.46
#
#    p2_SIG_STR_PCT  p1_TD_PCT  p2_TD_PCT p1_SUB_ATT p2_SUB_ATT p1_REV p2_REV  \
# 0            0.45        NaN        NaN          0          0      0      0
# 1            0.71       0.50        NaN          1          0      1      0
# 2            0.38       0.50       0.00          1          0      0      1
# 3            0.54       0.00       0.60          3          1      1      0
# 4            0.35       1.00       0.00          1          0      0      0
# 5            0.48       0.25       0.33          0          0      0      0
# 6            0.53        NaN        NaN          0          0      0      0
# 7            0.39       0.17        NaN          0          1      0      0
# 8            0.48       0.14       0.50          1          0      0      0
# 9            0.58       0.71        NaN          0          1      0      0
#
#    p1_CTRL  p2_CTRL p1_R1_KD p2_R1_KD  p1_R1_SIG_STR_PCT  p2_R1_SIG_STR_PCT  \
# 0        3        0        1        0               0.64               0.45
# 1      128        5        0        0               0.75               0.71
# 2      238       99        0        0               0.57               0.37
# 3      283      166        0        0               0.45               0.56
# 4       34       18        0        0               0.42               0.35
# 5      233      143        0        0               0.59               0.45
# 6       36        0        1        0               0.33               0.53
# 7      341        7        0        0               0.37               0.50
# 8      465       52        0        0               0.57               0.44
# 9      643        0        0        0               0.31               0.66
#
#    p1_R1_TD_PCT  p2_R1_TD_PCT p1_R1_SUB_ATT p2_R1_SUB_ATT p1_R1_REV p2_R1_REV  \
# 0           NaN           NaN             0             0         0         0
# 1          0.50           NaN             1             0         1         0
# 2           NaN           0.0             0             0         0         0
# 3           NaN           0.5             1             0         1         0
# 4          1.00           0.0             1             0         0         0
# 5          0.00           NaN             0             0         0         0
# 6           NaN           NaN             0             0         0         0
# 7          1.00           NaN             0             0         0         0
# 8          0.16           0.5             1             0         0         0
# 9          0.50           NaN             0             1         0         0
#
#    p1_R1_CTRL  p2_R1_CTRL  p1_SIG_STR_PCT_DETAILED  p2_SIG_STR_PCT_DETAILED  \
# 0           3           0                     0.64                     0.45
# 1         128           5                     0.75                     0.71
# 2           0           2                     0.59                     0.38
# 3          22          68                     0.40                     0.54
# 4          34          18                     0.42                     0.35
# 5          58          40                     0.51                     0.48
# 6          36           0                     0.33                     0.53
# 7         229           0                     0.48                     0.39
# 8         163          11                     0.55                     0.48
# 9         164           0                     0.46                     0.58
#
#    p1_R1_SIG_STR_PCT_DETAILED  p2_R1_SIG_STR_PCT_DETAILED  \
# 0                        0.64                        0.45
# 1                        0.75                        0.71
# 2                        0.57                        0.37
# 3                        0.45                        0.56
# 4                        0.42                        0.35
# 5                        0.59                        0.45
# 6                        0.33                        0.53
# 7                        0.37                        0.50
# 8                        0.57                        0.44
# 9                        0.31                        0.66
#
#                  method         referee  winner event_date  p1_SIG_STR_LANDED  \
# 0                KO/TKO    Marc Goddard       1        NaT                 11
# 1            Submission    Mike Beltran       1        NaT                 12
# 2  Decision - Unanimous    Marc Goddard       1        NaT                 65
# 3            Submission     Jim Perdios       0        NaT                 18
# 4            Submission     Jim Perdios       1        NaT                 26
# 5  Decision - Unanimous    Mike Beltran       1        NaT                 81
# 6                KO/TKO  Steve Perceval       1        NaT                 12
# 7  Decision - Unanimous      Matt Wynne       1        NaT                 43
# 8  Decision - Unanimous     Jim Perdios       1        NaT                 62
# 9  Decision - Unanimous  Steve Perceval       1        NaT                 41
#
#    p1_SIG_STR_ATTEMPTED  p2_SIG_STR_LANDED  p2_SIG_STR_ATTEMPTED  \
# 0                    17                  5                    11
# 1                    16                 10                    14
# 2                   109                 43                   113
# 3                    44                 31                    57
# 4                    61                 15                    42
# 5                   158                 43                    89
# 6                    36                  7                    13
# 7                    89                 46                   116
# 8                   111                 43                    89
# 9                    88                 48                    82
#
#    p1_TOTAL_STR_LANDED  p1_TOTAL_STR_ATTEMPTED  p2_TOTAL_STR_LANDED  \
# 0                   11                      17                    5
# 1                   12                      16                   10
# 2                   73                     123                   68
# 3                   28                      54                   73
# 4                   33                      69                   15
# 5                  101                     193                   62
# 6                   20                      48                    7
# 7                   47                      94                   55
# 8                  126                     199                   62
# 9                   99                     164                   75
#
#    p2_TOTAL_STR_ATTEMPTED  p1_TD_LANDED  p1_TD_ATTEMPTED  p2_TD_LANDED  \
# 0                      11             0                0             0
# 1                      14             2                4             0
# 2                     142             3                6             0
# 3                     103             0                1             3
# 4                      42             1                1             0
# 5                     111             1                4             2
# 6                      13             0                0             0
# 7                     129             3               17             0
# 8                     118             2               14             1
# 9                     115             5                7             0
#
#    p2_TD_ATTEMPTED  p1_R1_SIG_STR_LANDED  p1_R1_SIG_STR_ATTEMPTED  \
# 0                0                    11                       17
# 1                0                    12                       16
# 2                4                    32                       56
# 3                5                     9                       20
# 4                1                    26                       61
# 5                6                    37                       62
# 6                0                    12                       36
# 7                0                     3                        8
# 8                2                    43                       75
# 9                0                    10                       32
#
#    p2_R1_SIG_STR_LANDED  p2_R1_SIG_STR_ATTEMPTED  p1_R1_TOTAL_STR_LANDED  \
# 0                     5                       11                      11
# 1                    10                       14                      12
# 2                    16                       43                      32
# 3                    18                       32                      10
# 4                    15                       42                      33
# 5                    15                       33                      41
# 6                     7                       13                      20
# 7                     5                       10                       3
# 8                    12                       27                      72
# 9                    24                       36                      25
#
#    p1_R1_TOTAL_STR_ATTEMPTED  p2_R1_TOTAL_STR_LANDED  \
# 0                         17                       5
# 1                         16                      10
# 2                         56                      16
# 3                         21                      24
# 4                         69                      15
# 5                         67                      20
# 6                         48                       7
# 7                          9                       8
# 8                        111                      18
# 9                         56                      39
#
#    p2_R1_TOTAL_STR_ATTEMPTED  p1_R1_TD_LANDED  p1_R1_TD_ATTEMPTED  \
# 0                         11                0                   0
# 1                         14                2                   4
# 2                         43                0                   0
# 3                         38                0                   0
# 4                         42                1                   1
# 5                         38                0                   2
# 6                         13                0                   0
# 7                         14                2                   2
# 8                         36                1                   6
# 9                         52                1                   2
#
#    p2_R1_TD_LANDED  p2_R1_TD_ATTEMPTED  p1_HEAD_LANDED  p1_HEAD_ATTEMPTED  \
# 0                0                   0               6                  9
# 1                0                   0               3                  7
# 2                0                   1              29                 68
# 3                1                   2              11                 36
# 4                0                   1              13                 35
# 5                0                   0              44                102
# 6                0                   0               8                 31
# 7                0                   0              32                 74
# 8                1                   2              48                 95
# 9                0                   0              34                 77
#
#    p2_HEAD_LANDED  p2_HEAD_ATTEMPTED  p1_BODY_LANDED  p1_BODY_ATTEMPTED  \
# 0               0                  5               2                  3
# 1               9                 13               1                  1
# 2              36                 98              16                 21
# 3              28                 52               4                  4
# 4               7                 30               9                 20
# 5              21                 60              35                 53
# 6               0                  4               1                  2
# 7              32                 93               7                 10
# 8              26                 61               8                 10
# 9              31                 60               6                  9
#
#    p2_BODY_LANDED  p2_BODY_ATTEMPTED  p1_LEG_LANDED  p1_LEG_ATTEMPTED  \
# 0               1                  1              3                 5
# 1               0                  0              8                 8
# 2               6                 14             20                20
# 3               1                  2              3                 4
# 4               1                  5              4                 6
# 5              12                 19              2                 3
# 6               0                  1              3                 3
# 7               8                 13              4                 5
# 8               7                 10              6                 6
# 9               5                  6              1                 2
#
#    p2_LEG_LANDED  p2_LEG_ATTEMPTED  p1_DISTANCE_LANDED  p1_DISTANCE_ATTEMPTED  \
# 0              4                 5                   9                     15
# 1              1                 1                   9                     12
# 2              1                 1                  58                     95
# 3              2                 3                  15                     37
# 4              7                 7                  23                     55
# 5             10                10                  70                    145
# 6              7                 8                   8                     19
# 7              6                10                  40                     82
# 8             10                18                  15                     31
# 9             12                16                  12                     36
#
#    p2_DISTANCE_LANDED  p2_DISTANCE_ATTEMPTED  p1_CLINCH_LANDED  \
# 0                   5                     11                 0
# 1                  10                     14                 0
# 2                  38                    106                 4
# 3                  29                     52                 2
# 4                  14                     39                 3
# 5                  39                     81                10
# 6                   7                     13                 0
# 7                  37                     99                 3
# 8                  27                     62                 4
# 9                  46                     77                 1
#
#    p1_CLINCH_ATTEMPTED  p2_CLINCH_LANDED  p2_CLINCH_ATTEMPTED  \
# 0                    0                 0                    0
# 1                    0                 0                    0
# 2                    5                 0                    1
# 3                    4                 2                    5
# 4                    6                 0                    1
# 5                   12                 4                    6
# 6                    0                 0                    0
# 7                    6                 9                   16
# 8                    6                16                   25
# 9                    1                 1                    3
#
#    p1_GROUND_LANDED  p1_GROUND_ATTEMPTED  p2_GROUND_LANDED  \
# 0                 2                    2                 0
# 1                 3                    4                 0
# 2                 3                    9                 5
# 3                 1                    3                 0
# 4                 0                    0                 1
# 5                 1                    1                 0
# 6                 4                   17                 0
# 7                 0                    1                 0
# 8                43                   74                 0
# 9                28                   51                 1
#
#    p2_GROUND_ATTEMPTED  p1_R1_HEAD_LANDED  p1_R1_HEAD_ATTEMPTED  \
# 0                    0                  6                     9
# 1                    0                  3                     7
# 2                    6                 14                    33
# 3                    0                  4                    14
# 4                    2                 13                    35
# 5                    2                 21                    37
# 6                    0                  8                    31
# 7                    1                  1                     5
# 8                    2                 38                    70
# 9                    2                  8                    28
#
#    p2_R1_HEAD_LANDED  p2_R1_HEAD_ATTEMPTED  p1_R1_BODY_LANDED  \
# 0                  0                     5                  2
# 1                  9                    13                  1
# 2                 11                    34                 11
# 3                 16                    30                  3
# 4                  7                    30                  9
# 5                  4                    17                 15
# 6                  0                     4                  1
# 7                  2                     5                  0
# 8                  9                    20                  2
# 9                 11                    20                  2
#
#    p1_R1_BODY_ATTEMPTED  p2_R1_BODY_LANDED  p2_R1_BODY_ATTEMPTED  \
# 0                     3                  1                     1
# 1                     1                  0                     0
# 2                    16                  4                     8
# 3                     3                  0                     0
# 4                    20                  1                     5
# 5                    23                  5                    10
# 6                     2                  0                     1
# 7                     1                  0                     2
# 8                     2                  0                     1
# 9                     3                  3                     4
#
#    p1_R1_LEG_LANDED  p1_R1_LEG_ATTEMPTED  p2_R1_LEG_LANDED  \
# 0                 3                    5                 4
# 1                 8                    8                 1
# 2                 7                    7                 1
# 3                 2                    3                 2
# 4                 4                    6                 7
# 5                 1                    2                 6
# 6                 3                    3                 7
# 7                 2                    2                 3
# 8                 3                    3                 3
# 9                 0                    1                10
#
#    p2_R1_LEG_ATTEMPTED  p1_R1_DISTANCE_LANDED  p1_R1_DISTANCE_ATTEMPTED  \
# 0                    5                      9                        15
# 1                    1                      9                        12
# 2                    1                     29                        52
# 3                    2                      8                        18
# 4                    7                     23                        55
# 5                    6                     32                        56
# 6                    8                      8                        19
# 7                    3                      3                         7
# 8                    6                      6                        12
# 9                   12                      5                        24
#
#    p2_R1_DISTANCE_LANDED  p2_R1_DISTANCE_ATTEMPTED  p1_R1_CLINCH_LANDED  \
# 0                      5                        11                    0
# 1                     10                        14                    0
# 2                     16                        43                    3
# 3                     18                        31                    1
# 4                     14                        39                    3
# 5                     13                        30                    5
# 6                      7                        13                    0
# 7                      5                         9                    0
# 8                      9                        20                    0
# 9                     23                        34                    0
#
#    p1_R1_CLINCH_ATTEMPTED  p2_R1_CLINCH_LANDED  p2_R1_CLINCH_ATTEMPTED  \
# 0                       0                    0                       0
# 1                       0                    0                       0
# 2                       4                    0                       0
# 3                       2                    0                       1
# 4                       6                    0                       1
# 5                       6                    2                       3
# 6                       0                    0                       0
# 7                       0                    0                       0
# 8                       1                    3                       5
# 9                       0                    1                       2
#
#    p1_R1_GROUND_LANDED  p1_R1_GROUND_ATTEMPTED  p2_R1_GROUND_LANDED  \
# 0                    2                       2                    0
# 1                    3                       4                    0
# 2                    0                       0                    0
# 3                    0                       0                    0
# 4                    0                       0                    1
# 5                    0                       0                    0
# 6                    4                      17                    0
# 7                    0                       1                    0
# 8                   37                      62                    0
# 9                    5                       8                    0
#
#    p2_R1_GROUND_ATTEMPTED
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       2
# 5                       0
# 6                       0
# 7                       1
# 8                       2
# 9                       0

# %%
# merge the two datasets

# First, merge p1 fighter stats
fights_df = fights_df.merge(
    fighters_df,
    left_on='p1_fighter',
    right_on='name',  # This matches p1_fighter with the name column in fighters_df
    how='left'
)
fights_df.drop(columns=['name'], inplace=True)

# Only include the specific columns you want to rename with p1_ prefix
p1_cols = ['height', 'weight', 'reach', 'stance', 'dob', 'SLpM', 'Str. Acc.', 'SApM', 'Str. Def', 'TD Avg.', 'TD Acc.', 'TD Def.', 'Sub. Avg.']
fights_df.rename(columns={col: f'p1_{col}' for col in p1_cols}, inplace=True)

# Then merge p2 fighter stats
fights_df = fights_df.merge(
    fighters_df,
    left_on='p2_fighter',
    right_on='name',  # This matches p2_fighter with the name column in fighters_df
    how='left'
)
fights_df.drop(columns=['name'], inplace=True)

# Use the same columns for p2 as we did for p1
p2_cols = ['height', 'weight', 'reach', 'stance', 'dob', 'SLpM', 'Str. Acc.', 'SApM', 'Str. Def', 'TD Avg.', 'TD Acc.', 'TD Def.', 'Sub. Avg.']
fights_df.rename(columns={col: f'p2_{col}' for col in p2_cols}, inplace=True)


# Drop unwanted columns
columns_to_drop = ['record_x', 'wins_x', 'losses_x', 'draws_x', 'nc_x', 'record_y', 'wins_y', 'losses_y', 'draws_y', 'nc_y', 'url_x', 'url_y']

# Check if columns exist before trying to drop them
existing_columns = [col for col in columns_to_drop if col in fights_df.columns]
if existing_columns:
    fights_df.drop(columns=existing_columns, inplace=True)


#-------------------------
# cleaned_df = fights_df      # update the cleaned csv so that we cna retarin the features_df to update the model and calculating ema
#-------------------------


fights_df.head()
# Out:
#       p1_fighter        p2_fighter p1_KD p2_KD  p1_SIG_STR_PCT  \
# 0  Carlos Ulberg    Dominick Reyes     1     0            0.64
# 1    Jimmy Crute       Ivan Erslan     0     0            0.75
# 2   Jack Jenkins     Ramon Taveras     0     0            0.59
# 3  Jake Matthews        Neil Magny     0     0            0.40
# 4      Tom Nolan  Charlie Campbell     0     0            0.42
#
#    p2_SIG_STR_PCT  p1_TD_PCT  p2_TD_PCT p1_SUB_ATT p2_SUB_ATT p1_REV p2_REV  \
# 0            0.45        NaN        NaN          0          0      0      0
# 1            0.71        0.5        NaN          1          0      1      0
# 2            0.38        0.5        0.0          1          0      0      1
# 3            0.54        0.0        0.6          3          1      1      0
# 4            0.35        1.0        0.0          1          0      0      0
#
#    p1_CTRL  p2_CTRL p1_R1_KD p2_R1_KD  p1_R1_SIG_STR_PCT  p2_R1_SIG_STR_PCT  \
# 0        3        0        1        0               0.64               0.45
# 1      128        5        0        0               0.75               0.71
# 2      238       99        0        0               0.57               0.37
# 3      283      166        0        0               0.45               0.56
# 4       34       18        0        0               0.42               0.35
#
#    p1_R1_TD_PCT  p2_R1_TD_PCT p1_R1_SUB_ATT p2_R1_SUB_ATT p1_R1_REV p2_R1_REV  \
# 0           NaN           NaN             0             0         0         0
# 1           0.5           NaN             1             0         1         0
# 2           NaN           0.0             0             0         0         0
# 3           NaN           0.5             1             0         1         0
# 4           1.0           0.0             1             0         0         0
#
#    p1_R1_CTRL  p2_R1_CTRL  p1_SIG_STR_PCT_DETAILED  p2_SIG_STR_PCT_DETAILED  \
# 0           3           0                     0.64                     0.45
# 1         128           5                     0.75                     0.71
# 2           0           2                     0.59                     0.38
# 3          22          68                     0.40                     0.54
# 4          34          18                     0.42                     0.35
#
#    p1_R1_SIG_STR_PCT_DETAILED  p2_R1_SIG_STR_PCT_DETAILED  \
# 0                        0.64                        0.45
# 1                        0.75                        0.71
# 2                        0.57                        0.37
# 3                        0.45                        0.56
# 4                        0.42                        0.35
#
#                  method       referee  winner event_date  p1_SIG_STR_LANDED  \
# 0                KO/TKO  Marc Goddard       1        NaT                 11
# 1            Submission  Mike Beltran       1        NaT                 12
# 2  Decision - Unanimous  Marc Goddard       1        NaT                 65
# 3            Submission   Jim Perdios       0        NaT                 18
# 4            Submission   Jim Perdios       1        NaT                 26
#
#    p1_SIG_STR_ATTEMPTED  p2_SIG_STR_LANDED  p2_SIG_STR_ATTEMPTED  \
# 0                    17                  5                    11
# 1                    16                 10                    14
# 2                   109                 43                   113
# 3                    44                 31                    57
# 4                    61                 15                    42
#
#    p1_TOTAL_STR_LANDED  p1_TOTAL_STR_ATTEMPTED  p2_TOTAL_STR_LANDED  \
# 0                   11                      17                    5
# 1                   12                      16                   10
# 2                   73                     123                   68
# 3                   28                      54                   73
# 4                   33                      69                   15
#
#    p2_TOTAL_STR_ATTEMPTED  p1_TD_LANDED  p1_TD_ATTEMPTED  p2_TD_LANDED  \
# 0                      11             0                0             0
# 1                      14             2                4             0
# 2                     142             3                6             0
# 3                     103             0                1             3
# 4                      42             1                1             0
#
#    p2_TD_ATTEMPTED  p1_R1_SIG_STR_LANDED  p1_R1_SIG_STR_ATTEMPTED  \
# 0                0                    11                       17
# 1                0                    12                       16
# 2                4                    32                       56
# 3                5                     9                       20
# 4                1                    26                       61
#
#    p2_R1_SIG_STR_LANDED  p2_R1_SIG_STR_ATTEMPTED  p1_R1_TOTAL_STR_LANDED  \
# 0                     5                       11                      11
# 1                    10                       14                      12
# 2                    16                       43                      32
# 3                    18                       32                      10
# 4                    15                       42                      33
#
#    p1_R1_TOTAL_STR_ATTEMPTED  p2_R1_TOTAL_STR_LANDED  \
# 0                         17                       5
# 1                         16                      10
# 2                         56                      16
# 3                         21                      24
# 4                         69                      15
#
#    p2_R1_TOTAL_STR_ATTEMPTED  p1_R1_TD_LANDED  p1_R1_TD_ATTEMPTED  \
# 0                         11                0                   0
# 1                         14                2                   4
# 2                         43                0                   0
# 3                         38                0                   0
# 4                         42                1                   1
#
#    p2_R1_TD_LANDED  p2_R1_TD_ATTEMPTED  p1_HEAD_LANDED  p1_HEAD_ATTEMPTED  \
# 0                0                   0               6                  9
# 1                0                   0               3                  7
# 2                0                   1              29                 68
# 3                1                   2              11                 36
# 4                0                   1              13                 35
#
#    p2_HEAD_LANDED  p2_HEAD_ATTEMPTED  p1_BODY_LANDED  p1_BODY_ATTEMPTED  \
# 0               0                  5               2                  3
# 1               9                 13               1                  1
# 2              36                 98              16                 21
# 3              28                 52               4                  4
# 4               7                 30               9                 20
#
#    p2_BODY_LANDED  p2_BODY_ATTEMPTED  p1_LEG_LANDED  p1_LEG_ATTEMPTED  \
# 0               1                  1              3                 5
# 1               0                  0              8                 8
# 2               6                 14             20                20
# 3               1                  2              3                 4
# 4               1                  5              4                 6
#
#    p2_LEG_LANDED  p2_LEG_ATTEMPTED  p1_DISTANCE_LANDED  p1_DISTANCE_ATTEMPTED  \
# 0              4                 5                   9                     15
# 1              1                 1                   9                     12
# 2              1                 1                  58                     95
# 3              2                 3                  15                     37
# 4              7                 7                  23                     55
#
#    p2_DISTANCE_LANDED  p2_DISTANCE_ATTEMPTED  p1_CLINCH_LANDED  \
# 0                   5                     11                 0
# 1                  10                     14                 0
# 2                  38                    106                 4
# 3                  29                     52                 2
# 4                  14                     39                 3
#
#    p1_CLINCH_ATTEMPTED  p2_CLINCH_LANDED  p2_CLINCH_ATTEMPTED  \
# 0                    0                 0                    0
# 1                    0                 0                    0
# 2                    5                 0                    1
# 3                    4                 2                    5
# 4                    6                 0                    1
#
#    p1_GROUND_LANDED  p1_GROUND_ATTEMPTED  p2_GROUND_LANDED  \
# 0                 2                    2                 0
# 1                 3                    4                 0
# 2                 3                    9                 5
# 3                 1                    3                 0
# 4                 0                    0                 1
#
#    p2_GROUND_ATTEMPTED  p1_R1_HEAD_LANDED  p1_R1_HEAD_ATTEMPTED  \
# 0                    0                  6                     9
# 1                    0                  3                     7
# 2                    6                 14                    33
# 3                    0                  4                    14
# 4                    2                 13                    35
#
#    p2_R1_HEAD_LANDED  p2_R1_HEAD_ATTEMPTED  p1_R1_BODY_LANDED  \
# 0                  0                     5                  2
# 1                  9                    13                  1
# 2                 11                    34                 11
# 3                 16                    30                  3
# 4                  7                    30                  9
#
#    p1_R1_BODY_ATTEMPTED  p2_R1_BODY_LANDED  p2_R1_BODY_ATTEMPTED  \
# 0                     3                  1                     1
# 1                     1                  0                     0
# 2                    16                  4                     8
# 3                     3                  0                     0
# 4                    20                  1                     5
#
#    p1_R1_LEG_LANDED  p1_R1_LEG_ATTEMPTED  p2_R1_LEG_LANDED  \
# 0                 3                    5                 4
# 1                 8                    8                 1
# 2                 7                    7                 1
# 3                 2                    3                 2
# 4                 4                    6                 7
#
#    p2_R1_LEG_ATTEMPTED  p1_R1_DISTANCE_LANDED  p1_R1_DISTANCE_ATTEMPTED  \
# 0                    5                      9                        15
# 1                    1                      9                        12
# 2                    1                     29                        52
# 3                    2                      8                        18
# 4                    7                     23                        55
#
#    p2_R1_DISTANCE_LANDED  p2_R1_DISTANCE_ATTEMPTED  p1_R1_CLINCH_LANDED  \
# 0                      5                        11                    0
# 1                     10                        14                    0
# 2                     16                        43                    3
# 3                     18                        31                    1
# 4                     14                        39                    3
#
#    p1_R1_CLINCH_ATTEMPTED  p2_R1_CLINCH_LANDED  p2_R1_CLINCH_ATTEMPTED  \
# 0                       0                    0                       0
# 1                       0                    0                       0
# 2                       4                    0                       0
# 3                       2                    0                       1
# 4                       6                    0                       1
#
#    p1_R1_GROUND_LANDED  p1_R1_GROUND_ATTEMPTED  p2_R1_GROUND_LANDED  \
# 0                    2                       2                    0
# 1                    3                       4                    0
# 2                    0                       0                    0
# 3                    0                       0                    0
# 4                    0                       0                    1
#
#    p2_R1_GROUND_ATTEMPTED  p1_height  p1_weight  p1_reach p1_stance  \
# 0                       0       76.0      205.0      77.0  Orthodox
# 1                       0       74.0      205.0      74.0  Orthodox
# 2                       0       67.0      145.0      68.0    Switch
# 3                       0       71.0      170.0      73.0  Orthodox
# 4                       2       75.0      155.0      73.0  Southpaw
#
#        p1_dob  p1_SLpM  p1_Str. Acc.  p1_SApM  p1_Str. Def  p1_TD Avg.  \
# 0  1990-11-07     6.77          0.55     4.21         0.51        0.58
# 1  1996-03-04     4.17          0.52     3.68         0.42        4.20
# 2  1993-11-03     4.50          0.61     2.97         0.58        1.78
# 3  1994-08-19     3.44          0.43     2.63         0.60        1.51
# 4  2000-03-08     5.82          0.45     4.85         0.46        0.41
#
#    p1_TD Acc.  p1_TD Def.  p1_Sub. Avg.  p2_height  p2_weight  p2_reach  \
# 0        0.60        0.85           0.2       76.0      205.0      77.0
# 1        0.52        0.58           1.9       74.0      205.0      72.0
# 2        0.64        0.67           0.0       68.0      145.0      70.0
# 3        0.42        0.67           0.6       75.0      170.0      80.0
# 4        0.12        0.66           1.6       72.0      155.0      72.0
#
#   p2_stance      p2_dob  p2_SLpM  p2_Str. Acc.  p2_SApM  p2_Str. Def  \
# 0  Southpaw  1989-12-26     5.58          0.54     3.54         0.50
# 1  Orthodox  1991-11-15     2.50          0.44     5.17         0.55
# 2  Southpaw  1994-01-09     4.62          0.44     7.41         0.57
# 3  Orthodox  1987-08-03     3.45          0.46     2.47         0.51
# 4  Orthodox  1995-07-03     5.55          0.54     3.73         0.55
#
#    p2_TD Avg.  p2_TD Acc.  p2_TD Def.  p2_Sub. Avg.
# 0        0.31        0.28        0.82           0.3
# 1        0.50        0.20        0.64           0.0
# 2        0.00        0.00        1.00           0.0
# 3        2.15        0.39        0.55           0.2
# 4        2.95        0.40        0.71           0.0

# %%
f_df = pd.read_csv('ufc_cleaned.csv')

f_df = pd.concat([fights_df, f_df], ignore_index=True)

f_df.to_csv('ufc_cleaned.csv', index=False)
