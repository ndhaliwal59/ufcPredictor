# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
from datetime import datetime
import json

def get_fighter_links(): # gets the links to each fighters profile
    base_url = 'http://ufcstats.com/statistics/fighters?'
    all_links = set()
    
    for char in 'abcdefghijklmnopqrstuvwxyz':
        url = f"{base_url}char={char}&page=all"
        try:
            response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
            soup = BeautifulSoup(response.content, 'lxml')
            
            # Target the specific links in table rows
            for row in soup.select('tr.b-statistics__table-row'):
                link_tag = row.find('a', class_='b-link b-link_style_black')
                if link_tag and link_tag.has_attr('href'):
                    all_links.add(link_tag['href'])
                    
        except Exception as e:
            print(f"Error processing {char.upper()}: {str(e)}")
    
    return list(all_links)

# Usage
fighter_links = get_fighter_links()
print(f"Found {len(fighter_links)} unique fighter profiles")
# Out:
# Found 4320 unique fighter profiles

# %%
def parse_fighter_page(url): # scrapes the data needed from each fighters profile
    try:
        response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(response.content, 'lxml')
        
        data = {
            'name': extract_name(soup),
            'record': extract_record(soup),
            **extract_physical_stats(soup),
            **extract_performance_stats(soup)
        }
        return data
        
    except Exception as e:
        print(f"Error parsing {url}: {str(e)}")
        return None

def extract_name(soup):
    name_tag = soup.find('span', class_='b-content__title-highlight')
    return name_tag.get_text(strip=True) if name_tag else 'Missing'

def extract_record(soup):
    record_tag = soup.find('span', class_='b-content__title-record')
    return record_tag.get_text(strip=True).replace('Record: ', '') if record_tag else 'Missing'

def extract_physical_stats(soup):
    stats = {
        'height': 'Missing',
        'weight': 'Missing',
        'reach': 'Missing',
        'stance': 'Missing',
        'dob': 'Missing'
    }
    
    items = soup.find_all('li', class_='b-list__box-list-item_type_block')
    for item in items:
        title = item.find('i').get_text(strip=True) if item.find('i') else ''
        value = item.get_text(strip=True).replace(title, '') if title else item.get_text(strip=True)
        
        if 'Height:' in title:
            stats['height'] = value
        elif 'Weight:' in title:
            stats['weight'] = value
        elif 'Reach:' in title:
            stats['reach'] = value
        elif 'STANCE:' in title:
            stats['stance'] = value
        elif 'DOB:' in title:
            stats['dob'] = value
            
    return stats

def extract_performance_stats(soup):
    metrics = {
        'SLpM': 'Missing',
        'Str. Acc.': 'Missing',
        'SApM': 'Missing',
        'Str. Def': 'Missing',
        'TD Avg.': 'Missing',
        'TD Acc.': 'Missing',
        'TD Def.': 'Missing',
        'Sub. Avg.': 'Missing'
    }
    
    items = soup.find_all('li', class_='b-list__box-list-item_type_block')
    for item in items:
        title = item.find('i', class_='b-list__box-item-title_font_lowercase')
        if not title:
            continue
            
        title_text = title.get_text(strip=True).replace(':', '')
        value = item.get_text(strip=True).replace(title_text, '').strip()
        
        if title_text in metrics:
            metrics[title_text] = value
            
    return metrics

# Usage example
fighter_url = "http://ufcstats.com/fighter-details/f923e012414c883e"
print(parse_fighter_page(fighter_url))
# Out:
# {'name': 'Lauren Mueller', 'record': '5-3-0', 'height': '5\' 5"', 'weight': '125 lbs.', 'reach': '67"', 'stance': 'Orthodox', 'dob': 'Nov 15, 1991', 'SLpM': ':4.08', 'Str. Acc.': ':41%', 'SApM': ':3.77', 'Str. Def': ':58%', 'TD Avg.': ':0.70', 'TD Acc.': ':50%', 'TD Def.': ':71%', 'Sub. Avg.': ':0.0'}

# %%
def scrape_all_fighters_fast(save_interval=50): #scrapes data for all the fighters
    
    # Create output directory if it doesn't exist
    output_dir = "ufc_fighter_data"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Get timestamp for filename
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    # Get all fighter links
    print("Fetching all fighter profile links...")
    fighter_links = get_fighter_links()
    total_fighters = len(fighter_links)
    print(f"Found {total_fighters} unique fighter profiles")
    
    # Process each fighter
    all_fighter_data = []
    processed = 0
    errors = 0
    
    for i, link in enumerate(fighter_links):
        # Process the fighter
        print(f"\rProcessing fighter {i+1}/{total_fighters}: {link}", end="")
        
        try:
            fighter_data = parse_fighter_page(link)
            if fighter_data:
                # Add URL to the data
                fighter_data['url'] = link
                all_fighter_data.append(fighter_data)
                processed += 1
                
                # Save progress periodically
                if processed % save_interval == 0:
                    interim_filename = f"{output_dir}/ufc_fighters_interim_{timestamp}_{processed}.json"
                    with open(interim_filename, 'w') as f:
                        json.dump(all_fighter_data, f, indent=2)
                    print(f"\nSaved interim data for {processed} fighters to {interim_filename}")
            else:
                errors += 1
                print(f"\nWarning: No data returned for {link}")
        
        except Exception as e:
            errors += 1
            print(f"\nError processing {link}: {str(e)}")
    
    # Save final results
    final_filename = f"{output_dir}/ufc_fighters_complete_{timestamp}.json"
    with open(final_filename, 'w') as f:
        json.dump(all_fighter_data, f, indent=2)
    
    print(f"\nCompleted! Processed {processed} fighters out of {total_fighters} links")
    print(f"Encountered {errors} errors")
    print(f"Data saved to {final_filename}")
    
    return all_fighter_data

# Run the fast scraper
print("UFC Fighter Data Scraper starting...")
all_data = scrape_all_fighters_fast()
print("Scraping completed!")
df = pd.DataFrame(all_data)
df.to_csv('ufc_fighters_data.csv', index=False)
# Out:
# UFC Fighter Data Scraper starting...
# Fetching all fighter profile links...
# Found 4320 unique fighter profiles
# Processing fighter 50/4320: http://ufcstats.com/fighter-details/402ea3b5ee233852
# Saved interim data for 50 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_50.json
# Processing fighter 100/4320: http://ufcstats.com/fighter-details/4d5197f331c47290
# Saved interim data for 100 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_100.json
# Processing fighter 150/4320: http://ufcstats.com/fighter-details/f626118b6da0e020
# Saved interim data for 150 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_150.json
# Processing fighter 200/4320: http://ufcstats.com/fighter-details/f9a20a17d712ef7c
# Saved interim data for 200 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_200.json
# Processing fighter 250/4320: http://ufcstats.com/fighter-details/5eedbf1e9601be35
# Saved interim data for 250 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_250.json
# Processing fighter 300/4320: http://ufcstats.com/fighter-details/2ebfbe72ed703925
# Saved interim data for 300 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_300.json
# Processing fighter 350/4320: http://ufcstats.com/fighter-details/2b6fc1c02736833d
# Saved interim data for 350 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_350.json
# Processing fighter 400/4320: http://ufcstats.com/fighter-details/b6c6d1731ff00eeb
# Saved interim data for 400 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_400.json
# Processing fighter 450/4320: http://ufcstats.com/fighter-details/008dc37cca279def
# Saved interim data for 450 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_450.json
# Processing fighter 500/4320: http://ufcstats.com/fighter-details/27d65e9d0fba61ea
# Saved interim data for 500 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_500.json
# Processing fighter 550/4320: http://ufcstats.com/fighter-details/79cbdf233e5e0496
# Saved interim data for 550 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_550.json
# Processing fighter 600/4320: http://ufcstats.com/fighter-details/ff62013d2fce6d13
# Saved interim data for 600 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_600.json
# Processing fighter 650/4320: http://ufcstats.com/fighter-details/1ed32eaaba9ffe10
# Saved interim data for 650 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_650.json
# Processing fighter 700/4320: http://ufcstats.com/fighter-details/2a2eeee20ef049cf
# Saved interim data for 700 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_700.json
# Processing fighter 750/4320: http://ufcstats.com/fighter-details/96d173b7f92aa520
# Saved interim data for 750 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_750.json
# Processing fighter 800/4320: http://ufcstats.com/fighter-details/8c020156779f7888
# Saved interim data for 800 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_800.json
# Processing fighter 850/4320: http://ufcstats.com/fighter-details/c814b4c899793af6
# Saved interim data for 850 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_850.json
# Processing fighter 900/4320: http://ufcstats.com/fighter-details/6e15f63b6c2e2c15
# Saved interim data for 900 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_900.json
# Processing fighter 950/4320: http://ufcstats.com/fighter-details/a26198ba5093147e
# Saved interim data for 950 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_950.json
# Processing fighter 1000/4320: http://ufcstats.com/fighter-details/d0a5ef38a7778ac2
# Saved interim data for 1000 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1000.json
# Processing fighter 1050/4320: http://ufcstats.com/fighter-details/fd5b6598a3b70c0a
# Saved interim data for 1050 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1050.json
# Processing fighter 1100/4320: http://ufcstats.com/fighter-details/cc2fcae2c0dc501d
# Saved interim data for 1100 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1100.json
# Processing fighter 1150/4320: http://ufcstats.com/fighter-details/ef44e4ea9050f2ea
# Saved interim data for 1150 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1150.json
# Processing fighter 1200/4320: http://ufcstats.com/fighter-details/9c5f7d5c6d084b35
# Saved interim data for 1200 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1200.json
# Processing fighter 1250/4320: http://ufcstats.com/fighter-details/b93c06d09d1c4ac0
# Saved interim data for 1250 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1250.json
# Processing fighter 1300/4320: http://ufcstats.com/fighter-details/33011768c3c4dc9a
# Saved interim data for 1300 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1300.json
# Processing fighter 1350/4320: http://ufcstats.com/fighter-details/22f4b6cb6b1bd7fd
# Saved interim data for 1350 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1350.json
# Processing fighter 1400/4320: http://ufcstats.com/fighter-details/71ef1111bf829b82
# Saved interim data for 1400 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1400.json
# Processing fighter 1450/4320: http://ufcstats.com/fighter-details/bbfca6d5c27d9cd8
# Saved interim data for 1450 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1450.json
# Processing fighter 1500/4320: http://ufcstats.com/fighter-details/4a482a0100cfcd0a
# Saved interim data for 1500 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1500.json
# Processing fighter 1550/4320: http://ufcstats.com/fighter-details/47b63240018d5d86
# Saved interim data for 1550 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1550.json
# Processing fighter 1600/4320: http://ufcstats.com/fighter-details/3c85e04b08a05751
# Saved interim data for 1600 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1600.json
# Processing fighter 1650/4320: http://ufcstats.com/fighter-details/fcaae0385b514f11
# Saved interim data for 1650 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1650.json
# Processing fighter 1700/4320: http://ufcstats.com/fighter-details/1d688fa375d9431c
# Saved interim data for 1700 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1700.json
# Processing fighter 1750/4320: http://ufcstats.com/fighter-details/c046100aea0dba9a
# Saved interim data for 1750 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1750.json
# Processing fighter 1800/4320: http://ufcstats.com/fighter-details/864c07a7ff90caae
# Saved interim data for 1800 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1800.json
# Processing fighter 1850/4320: http://ufcstats.com/fighter-details/0d9312337fdce39a
# Saved interim data for 1850 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1850.json
# Processing fighter 1900/4320: http://ufcstats.com/fighter-details/a62f85f6a6c19a4c
# Saved interim data for 1900 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1900.json
# Processing fighter 1950/4320: http://ufcstats.com/fighter-details/348dff4e03bd18c6
# Saved interim data for 1950 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_1950.json
# Processing fighter 2000/4320: http://ufcstats.com/fighter-details/7c4ec656d8fcb867
# Saved interim data for 2000 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2000.json
# Processing fighter 2050/4320: http://ufcstats.com/fighter-details/e82b2adcaeff71ec
# Saved interim data for 2050 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2050.json
# Processing fighter 2100/4320: http://ufcstats.com/fighter-details/41cc71cbf210e0fe
# Saved interim data for 2100 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2100.json
# Processing fighter 2150/4320: http://ufcstats.com/fighter-details/cf772fb504842dc3
# Saved interim data for 2150 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2150.json
# Processing fighter 2200/4320: http://ufcstats.com/fighter-details/46f11d15c0134fe3
# Saved interim data for 2200 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2200.json
# Processing fighter 2250/4320: http://ufcstats.com/fighter-details/a5fa51a81d0c5ed9
# Saved interim data for 2250 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2250.json
# Processing fighter 2300/4320: http://ufcstats.com/fighter-details/aa1a873d05acc7eb
# Saved interim data for 2300 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2300.json
# Processing fighter 2350/4320: http://ufcstats.com/fighter-details/072a10e85f7d4bff
# Saved interim data for 2350 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2350.json
# Processing fighter 2400/4320: http://ufcstats.com/fighter-details/fccf811c1e8b01c7
# Saved interim data for 2400 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2400.json
# Processing fighter 2450/4320: http://ufcstats.com/fighter-details/dda67d7d3df6b406
# Saved interim data for 2450 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2450.json
# Processing fighter 2500/4320: http://ufcstats.com/fighter-details/8f7380fb0916dc77
# Saved interim data for 2500 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2500.json
# Processing fighter 2550/4320: http://ufcstats.com/fighter-details/ffc3e6daaa6da0b7
# Saved interim data for 2550 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2550.json
# Processing fighter 2600/4320: http://ufcstats.com/fighter-details/4679a38cced7c64a
# Saved interim data for 2600 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2600.json
# Processing fighter 2650/4320: http://ufcstats.com/fighter-details/e7ecfab8fd86d3e1
# Saved interim data for 2650 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2650.json
# Processing fighter 2700/4320: http://ufcstats.com/fighter-details/a54660deb6a8489c
# Saved interim data for 2700 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2700.json
# Processing fighter 2750/4320: http://ufcstats.com/fighter-details/a474aade8eb3a8f0
# Saved interim data for 2750 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2750.json
# Processing fighter 2800/4320: http://ufcstats.com/fighter-details/6551c64fbcd1a467
# Saved interim data for 2800 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2800.json
# Processing fighter 2850/4320: http://ufcstats.com/fighter-details/4c27ca8c8481f79a
# Saved interim data for 2850 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2850.json
# Processing fighter 2900/4320: http://ufcstats.com/fighter-details/4100c7a09497ad41
# Saved interim data for 2900 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2900.json
# Processing fighter 2950/4320: http://ufcstats.com/fighter-details/9e50097a89442158
# Saved interim data for 2950 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_2950.json
# Processing fighter 3000/4320: http://ufcstats.com/fighter-details/e51e5cb722bd47a8
# Saved interim data for 3000 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3000.json
# Processing fighter 3050/4320: http://ufcstats.com/fighter-details/7c35f869033901ae
# Saved interim data for 3050 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3050.json
# Processing fighter 3100/4320: http://ufcstats.com/fighter-details/feedf3053472fe56
# Saved interim data for 3100 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3100.json
# Processing fighter 3150/4320: http://ufcstats.com/fighter-details/7e208569469c8bc8
# Saved interim data for 3150 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3150.json
# Processing fighter 3200/4320: http://ufcstats.com/fighter-details/cc300e9aa3063431
# Saved interim data for 3200 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3200.json
# Processing fighter 3250/4320: http://ufcstats.com/fighter-details/70a1c7626b5e0599
# Saved interim data for 3250 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3250.json
# Processing fighter 3300/4320: http://ufcstats.com/fighter-details/ea398c802d9998ee
# Saved interim data for 3300 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3300.json
# Processing fighter 3350/4320: http://ufcstats.com/fighter-details/f562238becb9ec50
# Saved interim data for 3350 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3350.json
# Processing fighter 3400/4320: http://ufcstats.com/fighter-details/1c610f900f9884ab
# Saved interim data for 3400 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3400.json
# Processing fighter 3450/4320: http://ufcstats.com/fighter-details/513c6f1715e547a8
# Saved interim data for 3450 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3450.json
# Processing fighter 3500/4320: http://ufcstats.com/fighter-details/87f3bbf52e6c9dc9
# Saved interim data for 3500 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3500.json
# Processing fighter 3550/4320: http://ufcstats.com/fighter-details/35080a7f406f9ab3
# Saved interim data for 3550 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3550.json
# Processing fighter 3600/4320: http://ufcstats.com/fighter-details/39cc64bf0a269db9
# Saved interim data for 3600 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3600.json
# Processing fighter 3650/4320: http://ufcstats.com/fighter-details/979f7edbb6980b0d
# Saved interim data for 3650 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3650.json
# Processing fighter 3700/4320: http://ufcstats.com/fighter-details/ec7ac09293d26c05
# Saved interim data for 3700 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3700.json
# Processing fighter 3750/4320: http://ufcstats.com/fighter-details/e6904a03a66e711d
# Saved interim data for 3750 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3750.json
# Processing fighter 3800/4320: http://ufcstats.com/fighter-details/fa6796c55d6c5440
# Saved interim data for 3800 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3800.json
# Processing fighter 3850/4320: http://ufcstats.com/fighter-details/6fc506e1099afe20
# Saved interim data for 3850 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3850.json
# Processing fighter 3900/4320: http://ufcstats.com/fighter-details/d745d4146be48679
# Saved interim data for 3900 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3900.json
# Processing fighter 3950/4320: http://ufcstats.com/fighter-details/ebc5af72ad5a28cb
# Saved interim data for 3950 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_3950.json
# Processing fighter 4000/4320: http://ufcstats.com/fighter-details/af62f99eb7606308
# Saved interim data for 4000 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_4000.json
# Processing fighter 4050/4320: http://ufcstats.com/fighter-details/d71d968dc6ecfdaf
# Saved interim data for 4050 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_4050.json
# Processing fighter 4100/4320: http://ufcstats.com/fighter-details/5340123d826ceadb
# Saved interim data for 4100 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_4100.json
# Processing fighter 4150/4320: http://ufcstats.com/fighter-details/64db35f7782fe274
# Saved interim data for 4150 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_4150.json
# Processing fighter 4200/4320: http://ufcstats.com/fighter-details/0e5c4e72237461bb
# Saved interim data for 4200 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_4200.json
# Processing fighter 4250/4320: http://ufcstats.com/fighter-details/9e30f69cc0869301
# Saved interim data for 4250 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_4250.json
# Processing fighter 4300/4320: http://ufcstats.com/fighter-details/9dedfdd91070ddd8
# Saved interim data for 4300 fighters to ufc_fighter_data/ufc_fighters_interim_20250508_220431_4300.json
# Processing fighter 4320/4320: http://ufcstats.com/fighter-details/0be6776db31d98ec
# Completed! Processed 4320 fighters out of 4320 links
# Encountered 0 errors
# Data saved to ufc_fighter_data/ufc_fighters_complete_20250508_220431.json
# Scraping completed!
