# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
from datetime import datetime
import json

def get_fighter_links(): # gets the links to each fighters profile
    base_url = 'http://ufcstats.com/statistics/fighters?'
    all_links = set()
    
    for char in 'abcdefghijklmnopqrstuvwxyz':
        url = f"{base_url}char={char}&page=all"
        try:
            response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
            soup = BeautifulSoup(response.content, 'lxml')
            
            # Target the specific links in table rows
            for row in soup.select('tr.b-statistics__table-row'):
                link_tag = row.find('a', class_='b-link b-link_style_black')
                if link_tag and link_tag.has_attr('href'):
                    all_links.add(link_tag['href'])
                    
        except Exception as e:
            print(f"Error processing {char.upper()}: {str(e)}")
    
    return list(all_links)

# Usage
fighter_links = get_fighter_links()
print(f"Found {len(fighter_links)} unique fighter profiles")
# Out:
# Found 4437 unique fighter profiles

# %%
def parse_fighter_page(url): # scrapes the data needed from each fighters profile
    try:
        response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(response.content, 'lxml')
        
        data = {
            'name': extract_name(soup),
            'record': extract_record(soup),
            **extract_physical_stats(soup),
            **extract_performance_stats(soup)
        }
        return data
        
    except Exception as e:
        print(f"Error parsing {url}: {str(e)}")
        return None

def extract_name(soup):
    name_tag = soup.find('span', class_='b-content__title-highlight')
    return name_tag.get_text(strip=True) if name_tag else 'Missing'

def extract_record(soup):
    record_tag = soup.find('span', class_='b-content__title-record')
    return record_tag.get_text(strip=True).replace('Record: ', '') if record_tag else 'Missing'

def extract_physical_stats(soup):
    stats = {
        'height': 'Missing',
        'weight': 'Missing',
        'reach': 'Missing',
        'stance': 'Missing',
        'dob': 'Missing'
    }
    
    items = soup.find_all('li', class_='b-list__box-list-item_type_block')
    for item in items:
        title = item.find('i').get_text(strip=True) if item.find('i') else ''
        value = item.get_text(strip=True).replace(title, '') if title else item.get_text(strip=True)
        
        if 'Height:' in title:
            stats['height'] = value
        elif 'Weight:' in title:
            stats['weight'] = value
        elif 'Reach:' in title:
            stats['reach'] = value
        elif 'STANCE:' in title:
            stats['stance'] = value
        elif 'DOB:' in title:
            stats['dob'] = value
            
    return stats

def extract_performance_stats(soup):
    metrics = {
        'SLpM': 'Missing',
        'Str. Acc.': 'Missing',
        'SApM': 'Missing',
        'Str. Def': 'Missing',
        'TD Avg.': 'Missing',
        'TD Acc.': 'Missing',
        'TD Def.': 'Missing',
        'Sub. Avg.': 'Missing'
    }
    
    items = soup.find_all('li', class_='b-list__box-list-item_type_block')
    for item in items:
        title = item.find('i', class_='b-list__box-item-title_font_lowercase')
        if not title:
            continue
            
        title_text = title.get_text(strip=True).replace(':', '')
        value = item.get_text(strip=True).replace(title_text, '').strip()
        
        if title_text in metrics:
            metrics[title_text] = value
            
    return metrics

# Usage example
fighter_url = "http://ufcstats.com/fighter-details/f923e012414c883e"
print(parse_fighter_page(fighter_url))
# Out:
# {'name': 'Lauren Mueller', 'record': '5-3-0', 'height': '5\' 5"', 'weight': '125 lbs.', 'reach': '67"', 'stance': 'Orthodox', 'dob': 'Nov 15, 1991', 'SLpM': ':4.08', 'Str. Acc.': ':41%', 'SApM': ':3.77', 'Str. Def': ':58%', 'TD Avg.': ':0.70', 'TD Acc.': ':50%', 'TD Def.': ':71%', 'Sub. Avg.': ':0.0'}

# %%
def scrape_all_fighters_fast(save_interval=50): #scrapes data for all the fighters
    
    # Create output directory if it doesn't exist
    output_dir = "ufc_fighter_data"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Get timestamp for filename
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    # Get all fighter links
    print("Fetching all fighter profile links...")
    fighter_links = get_fighter_links()
    total_fighters = len(fighter_links)
    print(f"Found {total_fighters} unique fighter profiles")
    
    # Process each fighter
    all_fighter_data = []
    processed = 0
    errors = 0
    
    for i, link in enumerate(fighter_links):
        # Process the fighter
        print(f"\rProcessing fighter {i+1}/{total_fighters}: {link}", end="")
        
        try:
            fighter_data = parse_fighter_page(link)
            if fighter_data:
                # Add URL to the data
                fighter_data['url'] = link
                all_fighter_data.append(fighter_data)
                processed += 1
                
                # Save progress periodically
                if processed % save_interval == 0:
                    interim_filename = f"{output_dir}/ufc_fighters_interim_{timestamp}_{processed}.json"
                    with open(interim_filename, 'w') as f:
                        json.dump(all_fighter_data, f, indent=2)
                    print(f"\nSaved interim data for {processed} fighters to {interim_filename}")
            else:
                errors += 1
                print(f"\nWarning: No data returned for {link}")
        
        except Exception as e:
            errors += 1
            print(f"\nError processing {link}: {str(e)}")
    
    # Save final results
    final_filename = f"{output_dir}/ufc_fighters_complete_{timestamp}.json"
    with open(final_filename, 'w') as f:
        json.dump(all_fighter_data, f, indent=2)
    
    print(f"\nCompleted! Processed {processed} fighters out of {total_fighters} links")
    print(f"Encountered {errors} errors")
    print(f"Data saved to {final_filename}")
    
    return all_fighter_data

# Run the fast scraper
print("UFC Fighter Data Scraper starting...")
all_data = scrape_all_fighters_fast()
print("Scraping completed!")
df = pd.DataFrame(all_data)
df.to_csv('ufc_fighters_data.csv', index=False)
# Out:
# UFC Fighter Data Scraper starting...
# Fetching all fighter profile links...
# Found 4437 unique fighter profiles
# Processing fighter 50/4437: http://ufcstats.com/fighter-details/1433786ac76cf777
# Saved interim data for 50 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_50.json
# Processing fighter 100/4437: http://ufcstats.com/fighter-details/e1a4568fec1fc24f
# Saved interim data for 100 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_100.json
# Processing fighter 150/4437: http://ufcstats.com/fighter-details/49a74b9fb2e45fdf
# Saved interim data for 150 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_150.json
# Processing fighter 200/4437: http://ufcstats.com/fighter-details/3641a0d117e9bc6c
# Saved interim data for 200 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_200.json
# Processing fighter 250/4437: http://ufcstats.com/fighter-details/cf1a88371c8cb690
# Saved interim data for 250 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_250.json
# Processing fighter 300/4437: http://ufcstats.com/fighter-details/79f60d34ad48d7a3
# Saved interim data for 300 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_300.json
# Processing fighter 350/4437: http://ufcstats.com/fighter-details/6dd758d34da8d254
# Saved interim data for 350 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_350.json
# Processing fighter 400/4437: http://ufcstats.com/fighter-details/6dab8ce5e4bffe77
# Saved interim data for 400 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_400.json
# Processing fighter 450/4437: http://ufcstats.com/fighter-details/1d147d4163a6989b
# Saved interim data for 450 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_450.json
# Processing fighter 500/4437: http://ufcstats.com/fighter-details/6420efac0578988b
# Saved interim data for 500 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_500.json
# Processing fighter 550/4437: http://ufcstats.com/fighter-details/8a0a35e7c74bebcc
# Saved interim data for 550 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_550.json
# Processing fighter 600/4437: http://ufcstats.com/fighter-details/a049aa06508b9c7b
# Saved interim data for 600 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_600.json
# Processing fighter 650/4437: http://ufcstats.com/fighter-details/e6c5908910cc26e4
# Saved interim data for 650 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_650.json
# Processing fighter 700/4437: http://ufcstats.com/fighter-details/0c6d9ea8306c029e
# Saved interim data for 700 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_700.json
# Processing fighter 750/4437: http://ufcstats.com/fighter-details/91720876db0ee468
# Saved interim data for 750 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_750.json
# Processing fighter 800/4437: http://ufcstats.com/fighter-details/abd5fb12437eda21
# Saved interim data for 800 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_800.json
# Processing fighter 850/4437: http://ufcstats.com/fighter-details/41b34b7f11f6d085
# Saved interim data for 850 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_850.json
# Processing fighter 900/4437: http://ufcstats.com/fighter-details/a90c200c3fbb22c4
# Saved interim data for 900 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_900.json
# Processing fighter 950/4437: http://ufcstats.com/fighter-details/8e893f269d5696b2
# Saved interim data for 950 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_950.json
# Processing fighter 1000/4437: http://ufcstats.com/fighter-details/55ed59d541f8b90c
# Saved interim data for 1000 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1000.json
# Processing fighter 1050/4437: http://ufcstats.com/fighter-details/2ee09ec2a0695eb9
# Saved interim data for 1050 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1050.json
# Processing fighter 1100/4437: http://ufcstats.com/fighter-details/17923f676f100e16
# Saved interim data for 1100 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1100.json
# Processing fighter 1150/4437: http://ufcstats.com/fighter-details/c4b6099f0d25f75e
# Saved interim data for 1150 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1150.json
# Processing fighter 1200/4437: http://ufcstats.com/fighter-details/b6e6c3b1dcaae0a1
# Saved interim data for 1200 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1200.json
# Processing fighter 1250/4437: http://ufcstats.com/fighter-details/e872e9a9a902c045
# Saved interim data for 1250 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1250.json
# Processing fighter 1300/4437: http://ufcstats.com/fighter-details/c7d297714d9ab1a4
# Saved interim data for 1300 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1300.json
# Processing fighter 1350/4437: http://ufcstats.com/fighter-details/fe2babf95de24fb1
# Saved interim data for 1350 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1350.json
# Processing fighter 1400/4437: http://ufcstats.com/fighter-details/86ad0ae839331bd7
# Saved interim data for 1400 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1400.json
# Processing fighter 1450/4437: http://ufcstats.com/fighter-details/4798e823ada58fe9
# Saved interim data for 1450 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1450.json
# Processing fighter 1500/4437: http://ufcstats.com/fighter-details/8eb239a52fc4ec14
# Saved interim data for 1500 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1500.json
# Processing fighter 1550/4437: http://ufcstats.com/fighter-details/8765559b6a29a421
# Saved interim data for 1550 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1550.json
# Processing fighter 1600/4437: http://ufcstats.com/fighter-details/5095b0920a3602aa
# Saved interim data for 1600 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1600.json
# Processing fighter 1650/4437: http://ufcstats.com/fighter-details/e9213f53ddeca978
# Saved interim data for 1650 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1650.json
# Processing fighter 1700/4437: http://ufcstats.com/fighter-details/bad28b7b34f334de
# Saved interim data for 1700 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1700.json
# Processing fighter 1750/4437: http://ufcstats.com/fighter-details/e4770d5ed44a3970
# Saved interim data for 1750 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1750.json
# Processing fighter 1800/4437: http://ufcstats.com/fighter-details/e29cf523ebd155c5
# Saved interim data for 1800 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1800.json
# Processing fighter 1850/4437: http://ufcstats.com/fighter-details/71171fc96445bf65
# Saved interim data for 1850 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1850.json
# Processing fighter 1900/4437: http://ufcstats.com/fighter-details/31bb0772f21cabd8
# Saved interim data for 1900 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1900.json
# Processing fighter 1950/4437: http://ufcstats.com/fighter-details/5cdf5339728f580d
# Saved interim data for 1950 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_1950.json
# Processing fighter 2000/4437: http://ufcstats.com/fighter-details/ae4343d29c68e9d0
# Saved interim data for 2000 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2000.json
# Processing fighter 2050/4437: http://ufcstats.com/fighter-details/c34e5849184b08c3
# Saved interim data for 2050 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2050.json
# Processing fighter 2100/4437: http://ufcstats.com/fighter-details/013da757877044a2
# Saved interim data for 2100 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2100.json
# Processing fighter 2150/4437: http://ufcstats.com/fighter-details/ef5dcb10d2bd4b0f
# Saved interim data for 2150 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2150.json
# Processing fighter 2200/4437: http://ufcstats.com/fighter-details/696002b59f09d73b
# Saved interim data for 2200 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2200.json
# Processing fighter 2250/4437: http://ufcstats.com/fighter-details/fe5a9547479396ab
# Saved interim data for 2250 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2250.json
# Processing fighter 2300/4437: http://ufcstats.com/fighter-details/d247691a6c0e9034
# Saved interim data for 2300 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2300.json
# Processing fighter 2350/4437: http://ufcstats.com/fighter-details/8ebc3a8da015d70c
# Saved interim data for 2350 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2350.json
# Processing fighter 2400/4437: http://ufcstats.com/fighter-details/d311fbefff44a39b
# Saved interim data for 2400 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2400.json
# Processing fighter 2450/4437: http://ufcstats.com/fighter-details/9b1e3fb4f8cbd5b7
# Saved interim data for 2450 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2450.json
# Processing fighter 2500/4437: http://ufcstats.com/fighter-details/74b5736f1df40be3
# Saved interim data for 2500 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2500.json
# Processing fighter 2550/4437: http://ufcstats.com/fighter-details/1c7cce2f5c17160d
# Saved interim data for 2550 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2550.json
# Processing fighter 2600/4437: http://ufcstats.com/fighter-details/d562b12b8fe88336
# Saved interim data for 2600 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2600.json
# Processing fighter 2650/4437: http://ufcstats.com/fighter-details/92b5f4ee9ff40321
# Saved interim data for 2650 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2650.json
# Processing fighter 2700/4437: http://ufcstats.com/fighter-details/a314687f372b2cec
# Saved interim data for 2700 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2700.json
# Processing fighter 2750/4437: http://ufcstats.com/fighter-details/5df10509264586e5
# Saved interim data for 2750 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2750.json
# Processing fighter 2800/4437: http://ufcstats.com/fighter-details/231cae8b77fbbcc1
# Saved interim data for 2800 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2800.json
# Processing fighter 2850/4437: http://ufcstats.com/fighter-details/fb4ca5c7e4448645
# Saved interim data for 2850 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2850.json
# Processing fighter 2900/4437: http://ufcstats.com/fighter-details/1649770c649db6a5
# Saved interim data for 2900 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2900.json
# Processing fighter 2950/4437: http://ufcstats.com/fighter-details/a68d57ae177a5815
# Saved interim data for 2950 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_2950.json
# Processing fighter 3000/4437: http://ufcstats.com/fighter-details/49e7e05f902479ca
# Saved interim data for 3000 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3000.json
# Processing fighter 3050/4437: http://ufcstats.com/fighter-details/8d04923f2db59b7f
# Saved interim data for 3050 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3050.json
# Processing fighter 3100/4437: http://ufcstats.com/fighter-details/3c921b1a30fdcbdd
# Saved interim data for 3100 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3100.json
# Processing fighter 3150/4437: http://ufcstats.com/fighter-details/13e62d766b709aa6
# Saved interim data for 3150 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3150.json
# Processing fighter 3200/4437: http://ufcstats.com/fighter-details/592d23aed850e652
# Saved interim data for 3200 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3200.json
# Processing fighter 3250/4437: http://ufcstats.com/fighter-details/fdf59144e535bc38
# Saved interim data for 3250 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3250.json
# Processing fighter 3300/4437: http://ufcstats.com/fighter-details/841695e02c99a521
# Saved interim data for 3300 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3300.json
# Processing fighter 3350/4437: http://ufcstats.com/fighter-details/5e4eec08896c9423
# Saved interim data for 3350 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3350.json
# Processing fighter 3400/4437: http://ufcstats.com/fighter-details/19f8a2f6eecd92ac
# Saved interim data for 3400 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3400.json
# Processing fighter 3450/4437: http://ufcstats.com/fighter-details/307064d3e0f036c2
# Saved interim data for 3450 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3450.json
# Processing fighter 3500/4437: http://ufcstats.com/fighter-details/f54fb3b9c4228142
# Saved interim data for 3500 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3500.json
# Processing fighter 3550/4437: http://ufcstats.com/fighter-details/b4c6c904a9ffc5e8
# Saved interim data for 3550 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3550.json
# Processing fighter 3600/4437: http://ufcstats.com/fighter-details/a5cb1c29461853ca
# Saved interim data for 3600 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3600.json
# Processing fighter 3650/4437: http://ufcstats.com/fighter-details/4461d7e47375a895
# Saved interim data for 3650 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3650.json
# Processing fighter 3700/4437: http://ufcstats.com/fighter-details/646d5dbe509accd4
# Saved interim data for 3700 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3700.json
# Processing fighter 3750/4437: http://ufcstats.com/fighter-details/3623bd267a2eef2e
# Saved interim data for 3750 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3750.json
# Processing fighter 3800/4437: http://ufcstats.com/fighter-details/a8e133139286df84
# Saved interim data for 3800 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3800.json
# Processing fighter 3850/4437: http://ufcstats.com/fighter-details/947eccadb72f4f6f
# Saved interim data for 3850 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3850.json
# Processing fighter 3900/4437: http://ufcstats.com/fighter-details/f5431394fb284bb9
# Saved interim data for 3900 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3900.json
# Processing fighter 3950/4437: http://ufcstats.com/fighter-details/33e00249ef08d3a4
# Saved interim data for 3950 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_3950.json
# Processing fighter 4000/4437: http://ufcstats.com/fighter-details/2f95a3c6d58b2aad
# Saved interim data for 4000 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_4000.json
# Processing fighter 4050/4437: http://ufcstats.com/fighter-details/7b6e40a73b567072
# Saved interim data for 4050 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_4050.json
# Processing fighter 4100/4437: http://ufcstats.com/fighter-details/1f77fce698e80488
# Saved interim data for 4100 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_4100.json
# Processing fighter 4150/4437: http://ufcstats.com/fighter-details/7dfb56f24fe5ddea
# Saved interim data for 4150 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_4150.json
# Processing fighter 4200/4437: http://ufcstats.com/fighter-details/1e7483dbff40b84b
# Saved interim data for 4200 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_4200.json
# Processing fighter 4250/4437: http://ufcstats.com/fighter-details/970beed85bc46b63
# Saved interim data for 4250 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_4250.json
# Processing fighter 4300/4437: http://ufcstats.com/fighter-details/6e9f40c706f91f32
# Saved interim data for 4300 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_4300.json
# Processing fighter 4350/4437: http://ufcstats.com/fighter-details/3b6d84343579fd33
# Saved interim data for 4350 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_4350.json
# Processing fighter 4400/4437: http://ufcstats.com/fighter-details/adea9f0090aa8e14
# Saved interim data for 4400 fighters to ufc_fighter_data/ufc_fighters_interim_20250912_092021_4400.json
# Processing fighter 4437/4437: http://ufcstats.com/fighter-details/8ecb9f42da5ef5ac
# Completed! Processed 4437 fighters out of 4437 links
# Encountered 0 errors
# Data saved to ufc_fighter_data/ufc_fighters_complete_20250912_092021.json
# Scraping completed!
